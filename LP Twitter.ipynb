# %%
# snscrape twitter-search "corona since:2019-12-31 until:2020-09-25" > borrar.txt
import json
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import numpy as np
import pandas as pd

consumer_key = "UMqWhrvhnvlriQjUGsEdeFBun"
consumer_secret = "wKqdKBJsntpqd03EmPEMfyMf4FZnGF05RbF2oG80MxgMAr9Kui"
access_token = "229639629-yXLcOQJlI9U8f6qqCStZtufUv9x3b2wqpwwdLsqW"
access_token_secret = "rggSaGyuw6TOtfdg0tQsuXQAZdq6SIApeB5vs6Shv9wry"

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token , access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
def get_data(data): 
    return json.dumps(data._json, indent=2, ensure_ascii=False)

def get_data_Json(data):
    return data._json

def menciones(list):
    menciones = []
    for dic_mencion in list:
        mencion = dic_mencion['screen_name']
        menciones.append(mencion)
    return menciones

def get_hashtags(list_dic):
    l = []
    for dic_hashtag in list_dic:
        l.append(dic_hashtag['text'])
    return l

def diccionario_tw (tw):
    dic = {}
    dic["fecha"] = tw['created_at']
    dic["texto"] = tw['full_text']
    dic["longuitud"] = len( dic["texto"])
    dic_entity = tw['entities']
    list_hashtags = get_hashtags(dic_entity['hashtags'])
    dic["hashtags"] = list_hashtags
    dic["num_hashtags"] = len(list_hashtags)
    dic["mencions"] = menciones(dic_entity['user_mentions'])
    dic["num_mencions"] = len(menciones(dic_entity['user_mentions']))
    dic['language'] = tw['lang']
    dic['retweet_count'] = tw['retweet_count']
    dic['favorite_count'] = tw['favorite_count']
    
    dic_place = tw['place']
    if dic_place is not None:
        dic['name_place'] = dic_place['name']
        dic['full_name_place'] = dic_place['full_name']
        dic['country'] = dic_place['country']
    else:
        dic['name_place'] = np.nan
        dic['full_name_place'] = np.nan
        dic['country'] = np.nan



    dic_user = tw['user']
    dic["username"] = dic_user['screen_name']
    dic["followers"] = dic_user['followers_count']
    dic["friends"] = dic_user['friends_count']
    dic["create_count"] = dic_user['created_at']

    return dic



def get_info_tweets(list_of_tweet):
    lista_tweets = []
    for tweet in list_of_tweet:
        tw = get_data_Json(tweet)
        dicc = diccionario_tw(tw)
        lista_tweets.append(dicc)
    return lista_tweets




def get_tweets_from_tweepy(keywords=[], hashtags=[], mencions=[], fecha_inicio=None, fecha_fin=None, country='',
                          min_replies=None, min_faves=None, min_retweets=None, username=None, language=None,
                          min_hashtags=None, min_mencions=None, fecha_min_creation_user=None, fecha_max_creation_user=None,
                          min_followers=None, min_friends=None, len_min_tweet=None):
    filters = ''

    if  country!='':
        country_id = api.geo_search(query=country, granularity="country")[0].id
        filters += 'place:%s ' %country_id
    if min_replies is not None and min_replies!='':
        filters += 'min_replies:%d ' %min_replies
    if min_faves is not None and min_faves!='':
        filters += 'min_faves:%d ' %min_faves
    if min_retweets is not None and min_retweets!='':
        filters += 'min_retweets:%d ' %min_retweets
    if username is not None and username!='':
        filters += 'from:%s ' %username

    hashtags = ['#'+x for x in hashtags]
    mencions = ['@'+x for x in mencions]
    keywords = ' OR '.join(keywords+hashtags+mencions)

    new_tweets = tweepy.Cursor(api.search, 
                               q='(%s) %s' % (keywords, filters), 
                               since = fecha_inicio,
                               until = fecha_fin,
                               tweet_mode='extended',
                               include_entities=True,
                               count=100,
                               lang=language,
                               ).items(1000)

    return get_info_tweets(list(new_tweets))  #Convert  list of Tweepy's tweets into list of info requierer 

from datetime import timedelta 

def get_DataFrame(tweets, filtros=None):
    if len(tweets)==0:
        return None
    df = pd.DataFrame(tweets)
    df['fecha'] = pd.to_datetime(df['fecha']) - timedelta(hours=5)  
    df['create_count'] = pd.to_datetime(df['create_count'])
    df.set_index('fecha', inplace=True)

    return df

# %%
tweets_apis = get_tweets_from_tweepy(['a'], country='Ecuador')
tweets_apis
# Out:
# Rate limit reached. Sleeping for: 118
# [{'fecha': 'Mon Jan 18 17:28:43 +0000 2021',
#   'texto': 'en verdad el banco de pichincha y diners club no tienen sentido común.\nLa persecución a sus clientes desde la pandemia es una locura.\nDebería de ser penado el acoso y la entrega de tus datos.',
#   'longuitud': 191,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Samborondon',
#   'full_name_place': 'Samborondon, Ecuador',
#   'country': 'Ecuador',
#   'username': 'FranFerreroMD',
#   'followers': 8088,
#   'friends': 894,
#   'create_count': 'Sun Oct 18 21:01:54 +0000 2009'},
#  {'fecha': 'Mon Jan 18 17:28:26 +0000 2021',
#   'texto': 'Nunca más voy a luchar por demostrar quién soy; Porque al final, creen lo que les conviene creer.',
#   'longuitud': 97,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Babahoyo',
#   'full_name_place': 'Babahoyo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'naomizquierdo',
#   'followers': 268,
#   'friends': 987,
#   'create_count': 'Sat Dec 26 16:22:10 +0000 2015'},
#  {'fecha': 'Mon Jan 18 17:28:23 +0000 2021',
#   'texto': 'Constatamos la etapa de 👨\u200d🏫capacitaciones de refuerzo que dicta el @cneimbabura a los Coordinadores de Mesa. \n\nTras el primer #SimulacroElectoralEc, que nos dejó algunos aprendizajes, fortalecemos al Talento Humano para que las #Elecciones2021Ec se cumplan efectivamente. 🇪🇨🗳 https://t.co/ce5zSxaAOf',
#   'longuitud': 299,
#   'hashtags': ['SimulacroElectoralEc', 'Elecciones2021Ec'],
#   'num_hashtags': 2,
#   'mencions': ['cneimbabura'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Imbabura',
#   'full_name_place': 'Imbabura, Ecuador',
#   'country': 'Ecuador',
#   'username': 'pponce_comunica',
#   'followers': 1569,
#   'friends': 1610,
#   'create_count': 'Thu Jan 10 16:39:50 +0000 2013'},
#  {'fecha': 'Mon Jan 18 17:27:56 +0000 2021',
#   'texto': 'Entrena Dani 🏃🏼\u200d♀️entrena!🏃🏼\u200d♀️..para que no seas como "otra" que culpa a diciembre cuando estaba gorda desde agosto! 🤣 Se pasa mi entrenador👹 pero es lo máximo 🤼\u200d♀️ Toma de medidas, superada 🤩 Nos vemos en el entrenamiento de la tardecita 💪🏼',
#   'longuitud': 242,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Ciudad Comercial El Dorado',
#   'full_name_place': 'Ciudad Comercial El Dorado',
#   'country': 'Ecuador',
#   'username': 'Dama_2103',
#   'followers': 468,
#   'friends': 295,
#   'create_count': 'Thu May 31 18:30:22 +0000 2012'},
#  {'fecha': 'Mon Jan 18 17:26:52 +0000 2021',
#   'texto': '#EntrevistaPolítica🎙️\nEste martes 19 de enero, Fernando Insua conversará con @juan_nebel, actual Presidente de #ACE, sobre temas de actualidad nacional.\n\nLos esperamos a partir de las 10h00 en nuestro #InstagramLive por @infograma.n✔️ #InteligenciaColectiva https://t.co/9CJmperJeX',
#   'longuitud': 281,
#   'hashtags': ['EntrevistaPolítica',
#    'ACE',
#    'InstagramLive',
#    'InteligenciaColectiva'],
#   'num_hashtags': 4,
#   'mencions': ['juan_nebel', 'INFOGRAMA'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'InfogramaN',
#   'followers': 1359,
#   'friends': 11,
#   'create_count': 'Wed May 13 14:00:05 +0000 2020'},
#  {'fecha': 'Mon Jan 18 17:26:28 +0000 2021',
#   'texto': 'Ya me hice la prueba de COVID19.\n\nAhora toca esperar a ver si es amigdalitis o coronavicho.',
#   'longuitud': 91,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'metalleomon',
#   'followers': 1374,
#   'friends': 673,
#   'create_count': 'Sat Jan 30 00:05:37 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:24:04 +0000 2021',
#   'texto': 'Que un candidato hable a favor del aborto en media elección...la militancia da resultados,vientos de cambio.💚\n#SeraLey',
#   'longuitud': 118,
#   'hashtags': ['SeraLey'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Latacunga',
#   'full_name_place': 'Latacunga, Ecuador',
#   'country': 'Ecuador',
#   'username': 'LizCucuMoreno',
#   'followers': 1176,
#   'friends': 60,
#   'create_count': 'Tue Aug 02 19:38:12 +0000 2016'},
#  {'fecha': 'Mon Jan 18 17:23:30 +0000 2021',
#   'texto': 'La familia de la Prefectura de Morona Santiago, deseamos un FELIZ CUMPLEAÑOS a nuestra autoridad provincial, prefecto Rafael Antuni.\n\nNuestros mejores deseos para que continúe trabajando por Morona Santiago.\n\n¡Felicidades estimado Prefecto! https://t.co/QoaPyPcdzx',
#   'longuitud': 264,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Morona',
#   'full_name_place': 'Morona, Ecuador',
#   'country': 'Ecuador',
#   'username': 'PrefecturaMS',
#   'followers': 2397,
#   'friends': 741,
#   'create_count': 'Fri Jun 22 19:40:15 +0000 2012'},
#  {'fecha': 'Mon Jan 18 17:23:21 +0000 2021',
#   'texto': '@LassoGuillermo @yakuperezg Vamos haciendo algo, @ecuarauz devuelve lo que NUNCA A ROBADO y tú devuelves lo que SI ROBASTE en el FERIADO BANCARIO.',
#   'longuitud': 146,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['LassoGuillermo', 'yakuperezg', 'ecuarauz'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'wgomezr',
#   'followers': 19302,
#   'friends': 3353,
#   'create_count': 'Thu Apr 07 22:09:08 +0000 2016'},
#  {'fecha': 'Mon Jan 18 17:22:32 +0000 2021',
#   'texto': '#MiVeci cada vez más cerca! En este #LunesDeGanarSeguidores empezamos trabajando como nos gusta, a pie desde los barrios con la gente🇪🇨🤗💜\n#CeliPresidente2021 #SandraLopez23 #Suma23 #YaTengoPorQuienVotar https://t.co/clQ3zIkwj3',
#   'longuitud': 226,
#   'hashtags': ['MiVeci',
#    'LunesDeGanarSeguidores',
#    'CeliPresidente2021',
#    'SandraLopez23',
#    'Suma23',
#    'YaTengoPorQuienVotar'],
#   'num_hashtags': 6,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 3,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'SandryLopezSuma',
#   'followers': 69,
#   'friends': 55,
#   'create_count': 'Wed Aug 26 16:41:03 +0000 2020'},
#  {'fecha': 'Mon Jan 18 17:22:11 +0000 2021',
#   'texto': '@SofiaEspinRC Y apoyo 7 veces si a Trujillo, en la desinstitucionalizacion del país.',
#   'longuitud': 84,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['SofiaEspinRC'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Rumiñahui',
#   'full_name_place': 'Rumiñahui, Ecuador',
#   'country': 'Ecuador',
#   'username': 'silviaflor077',
#   'followers': 130,
#   'friends': 306,
#   'create_count': 'Sun Aug 04 01:56:35 +0000 2013'},
#  {'fecha': 'Mon Jan 18 17:20:15 +0000 2021',
#   'texto': 'Aún sigo esperando que @ClaroEcua solucione el problema de la conexión a internet, llamadas, mensajes y quejas no han dado la solución respectiva.',
#   'longuitud': 146,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ClaroEcua'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'BscThony',
#   'followers': 192,
#   'friends': 1230,
#   'create_count': 'Thu Dec 09 04:58:02 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:18:37 +0000 2021',
#   'texto': 'Y como dije un día, me las iba a mandar a hacer! Otras más para la colección! https://t.co/hqD0DRV4Dp',
#   'longuitud': 101,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 2,
#   'favorite_count': 12,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'davidceva30',
#   'followers': 2017,
#   'friends': 48,
#   'create_count': 'Wed Oct 27 03:57:44 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:18:11 +0000 2021',
#   'texto': '@DoraOrdonezC @ObrasPublicasEc @emac_ep @goberazuay .@ObrasPublicasEc da mantenimiento a esta y otras vías de la Zona 6 con apoyo de personal de microempresas, por administración directa. También se ejecuta limpieza de deslizamientos conforme se producen.\nEnviaremos cuadrilla de trabajadores para desbroce en este sector.',
#   'longuitud': 322,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['DoraOrdonezC',
#    'ObrasPublicasEc',
#    'emac_ep',
#    'goberazuay',
#    'ObrasPublicasEc'],
#   'num_mencions': 5,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Daviidjm',
#   'followers': 149,
#   'friends': 218,
#   'create_count': 'Mon Mar 14 02:49:36 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:17:29 +0000 2021',
#   'texto': 'Caleb no sabe que juguete va a escoger...!!! en VILLA DEL REY - Reina Isabel. https://t.co/dGt7hW3KKS',
#   'longuitud': 101,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Daule',
#   'full_name_place': 'Daule, Ecuador',
#   'country': 'Ecuador',
#   'username': 'dogorschopper88',
#   'followers': 124,
#   'friends': 383,
#   'create_count': 'Sat Mar 19 06:47:26 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:16:45 +0000 2021',
#   'texto': '🐾Nada se compara al aparato olfativo canino 🐶 aprovechar esta habilidad natural para detectar pacientes positivos de #COVID19 es una actividad digna de felicitar a Working Dogs WDK-9 en la provincia de Pichincha.\n#NoPodemosParar ✅\nFuente: @teleamazonasec 📌 https://t.co/ZUssfPYtKn',
#   'longuitud': 280,
#   'hashtags': ['COVID19', 'NoPodemosParar'],
#   'num_hashtags': 2,
#   'mencions': ['teleamazonasec'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 3,
#   'favorite_count': 4,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'analialedesmaec',
#   'followers': 4445,
#   'friends': 205,
#   'create_count': 'Wed May 08 23:37:16 +0000 2013'},
#  {'fecha': 'Mon Jan 18 17:16:37 +0000 2021',
#   'texto': 'Los beneficios que tenemos son geniales. \nDebemos ser constantes y practicar las habilidades de nuestros peques a diario. \n#jardindeinfantes #Guayaquil #cdlamiraflores #cdihuellas en CDI Huellas https://t.co/lZyqTKUwZP',
#   'longuitud': 218,
#   'hashtags': ['jardindeinfantes',
#    'Guayaquil',
#    'cdlamiraflores',
#    'cdihuellas'],
#   'num_hashtags': 4,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'cdihuellas',
#   'followers': 193,
#   'friends': 326,
#   'create_count': 'Thu Feb 17 02:48:03 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:14:14 +0000 2021',
#   'texto': '@juanseroldan @MaxTVonline_EC Esto me huele a cuento primero que en enero llegaban 50 mil luego que 86mil ahora nos dicen que si  86 mil pero de a poco  hasta marzo',
#   'longuitud': 164,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['juanseroldan', 'MaxTVonline_EC'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Portoviejo',
#   'full_name_place': 'Portoviejo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'FelixArmandoOr1',
#   'followers': 5,
#   'friends': 97,
#   'create_count': 'Sat Nov 28 19:38:20 +0000 2015'},
#  {'fecha': 'Mon Jan 18 17:12:31 +0000 2021',
#   'texto': 'Romero ayer consiguió 2 votos más.. De la rana platanera y el incendiario!... Luego que dijo que el primer día se va a pegar la borrachera del carajo!... #DebatePresidencial2021 #ArauzPresidente2021',
#   'longuitud': 198,
#   'hashtags': ['DebatePresidencial2021', 'ArauzPresidente2021'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Loja',
#   'full_name_place': 'Loja, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Voladorhuellero',
#   'followers': 167,
#   'friends': 162,
#   'create_count': 'Tue Jun 07 01:55:10 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:11:16 +0000 2021',
#   'texto': '@luisantonio_r No “señor periodista” deje la ignorancia y la mala fe por un instante de su vida, a veces parece que se hacen, pero más seguro es que son.',
#   'longuitud': 153,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['luisantonio_r'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Jhon_569',
#   'followers': 38,
#   'friends': 218,
#   'create_count': 'Wed Nov 07 04:11:36 +0000 2012'},
#  {'fecha': 'Mon Jan 18 17:08:32 +0000 2021',
#   'texto': 'Por cierto ayer me llego un cargamento de chifles 🤤😋 desde Portoviejo, gracias a mi compa @Cristhianlopz y a @Jessica82232393 por traerlos.',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['Cristhianlopz', 'Jessica82232393'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'RoddyLopz',
#   'followers': 2794,
#   'friends': 2320,
#   'create_count': 'Thu Oct 21 16:45:00 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:08:21 +0000 2021',
#   'texto': 'pedidos para llevar a domicilio llame o whasat 0994182727 https://t.co/nlpfipJL3r',
#   'longuitud': 81,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Terminal Terrestre De Ibarra',
#   'full_name_place': 'Terminal Terrestre De Ibarra',
#   'country': 'Ecuador',
#   'username': 'IbarraChifa',
#   'followers': 7,
#   'friends': 27,
#   'create_count': 'Thu Apr 16 02:30:33 +0000 2020'},
#  {'fecha': 'Mon Jan 18 17:08:14 +0000 2021',
#   'texto': 'Espero hacer esto con la persona con quien me vaya a casar (si es que algún día lo hago).\nPero yo lo haría viendo un partido y le lancen un pelotazo y dentro de la pelota este escrito el papelito y el anillo 😂😂😂 https://t.co/Vo69Ca6KDq',
#   'longuitud': 235,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'JosueMilito97',
#   'followers': 2036,
#   'friends': 852,
#   'create_count': 'Wed May 12 04:53:11 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:07:36 +0000 2021',
#   'texto': 'Como empezamos debemos terminar, a meterle fuego panitas buen inicio de semana 👽🤘🏻',
#   'longuitud': 82,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Riobamba',
#   'full_name_place': 'Riobamba, Ecuador',
#   'country': 'Ecuador',
#   'username': 'AndresT30619306',
#   'followers': 25,
#   'friends': 281,
#   'create_count': 'Wed May 29 13:32:58 +0000 2019'},
#  {'fecha': 'Mon Jan 18 17:07:27 +0000 2021',
#   'texto': 'I am a little confused. Does @SamsungUS Galaxy S21 Ultra unlocked phone has micro sd card slot? I am just waiting the real answer to buy. 🙂\n#SamsungGalaxyS21Ultra',
#   'longuitud': 162,
#   'hashtags': ['SamsungGalaxyS21Ultra'],
#   'num_hashtags': 1,
#   'mencions': ['SamsungUS'],
#   'num_mencions': 1,
#   'language': 'en',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'SantyAbril',
#   'followers': 124,
#   'friends': 511,
#   'create_count': 'Wed Jun 15 00:57:27 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:06:57 +0000 2021',
#   'texto': '📌 A partir del 1️⃣5️⃣ de #Enero2021 el @SRIoficialEc informó que las #Sociedades deben solicitar la #ClaveSRI en línea a través de https://t.co/9rMb8w3j5W \n👉 Utilizando firma electrónica y a través de Quipux . https://t.co/euloI2D80X',
#   'longuitud': 233,
#   'hashtags': ['Enero2021', 'Sociedades', 'ClaveSRI'],
#   'num_hashtags': 3,
#   'mencions': ['SRIoficialEc'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'CONTRIBUTACION',
#   'followers': 229,
#   'friends': 362,
#   'create_count': 'Fri Jul 08 16:10:45 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:06:25 +0000 2021',
#   'texto': '⚠️ ¡Pilas! Hasta hoy podrás inscribirte para rendir el Examen de Acceso a la Educación Superior.\n\nIngresando a 👉 https://t.co/eTuStGU5pW, asegúrate de completar todos los pasos y al finalizar recuerda guardar el comprobante.\n\n👨\u200d🎓 #EAES2021 https://t.co/5YLq7lWxq2',
#   'longuitud': 263,
#   'hashtags': ['EAES2021'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Nobol',
#   'full_name_place': 'Nobol',
#   'country': 'Ecuador',
#   'username': 'InfocentroNobol',
#   'followers': 504,
#   'friends': 1711,
#   'create_count': 'Tue Aug 18 03:57:26 +0000 2015'},
#  {'fecha': 'Mon Jan 18 17:05:49 +0000 2021',
#   'texto': 'Reforcemos en casa con nuestros peques sus habilidades motrices.\n#jardíninfantil #preescolar #inicial #cdihuellas en CDI Huellas https://t.co/jsohTooV6F',
#   'longuitud': 152,
#   'hashtags': ['jardíninfantil', 'preescolar', 'inicial', 'cdihuellas'],
#   'num_hashtags': 4,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'cdihuellas',
#   'followers': 193,
#   'friends': 326,
#   'create_count': 'Thu Feb 17 02:48:03 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:05:08 +0000 2021',
#   'texto': '@BenBugsyS Te dan demasiado poco tiempo, ¿pero no vas a los debates? (Fueron 3 debates y solo fuiste al obligatorio) @ecuarauz habla serio. #Elecciones2021Ec https://t.co/3h14VvSYwD',
#   'longuitud': 181,
#   'hashtags': ['Elecciones2021Ec'],
#   'num_hashtags': 1,
#   'mencions': ['BenBugsyS', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Ecuador',
#   'full_name_place': 'Ecuador',
#   'country': 'Ecuador',
#   'username': 'freddyferruzola',
#   'followers': 1767,
#   'friends': 2308,
#   'create_count': 'Sun Sep 19 03:20:45 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:05:05 +0000 2021',
#   'texto': '@davidchenco1987 De una, te las llevo a casa. Confirma cuantas y para cuando',
#   'longuitud': 76,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['davidchenco1987'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'RoddyLopz',
#   'followers': 2794,
#   'friends': 2320,
#   'create_count': 'Thu Oct 21 16:45:00 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:04:57 +0000 2021',
#   'texto': '@LassoGuillermo tienes el descaro de llamar a otros de ladrones cuando tu eres el responsable de feriado bancario que fue la causa directa de migración de la muerte de personas de la tercera edad tu RATA eres el que menos calidad moral tienes para cuestionar',
#   'longuitud': 258,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['LassoGuillermo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'VinicioValenci2',
#   'followers': 21,
#   'friends': 54,
#   'create_count': 'Sat May 14 03:29:29 +0000 2016'},
#  {'fecha': 'Mon Jan 18 17:03:48 +0000 2021',
#   'texto': 'A veces las buenas amistades vuelven a encontrase.✨\n#Ecuador #pailondeldiablo #bañosdeaguasanta https://t.co/iBKYztVNBU',
#   'longuitud': 119,
#   'hashtags': ['Ecuador', 'pailondeldiablo', 'bañosdeaguasanta'],
#   'num_hashtags': 3,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'valenlindao',
#   'followers': 14,
#   'friends': 36,
#   'create_count': 'Tue Aug 20 06:08:27 +0000 2019'},
#  {'fecha': 'Mon Jan 18 17:03:39 +0000 2021',
#   'texto': '@DanielRodMD Todos los esfuerzos dedicados a diagnosticar SARS-COV-2',
#   'longuitud': 68,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['DanielRodMD'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'gabizambranoMD',
#   'followers': 1385,
#   'friends': 2362,
#   'create_count': 'Thu Aug 13 22:08:02 +0000 2015'},
#  {'fecha': 'Mon Jan 18 17:03:09 +0000 2021',
#   'texto': '@FridaJSG CARE TUCA. SE LLEVO LA PLATA DE COCA CODO SINGLER. GRACIAS A LA MUERTE DE SU CULION.',
#   'longuitud': 94,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['FridaJSG'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'PautasSin',
#   'followers': 440,
#   'friends': 1901,
#   'create_count': 'Sun May 17 03:30:38 +0000 2020'},
#  {'fecha': 'Mon Jan 18 17:02:37 +0000 2021',
#   'texto': '@Rubiu5 violo a mi perro hijo de puta',
#   'longuitud': 37,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['Rubiu5'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'samueldiazx',
#   'followers': 11,
#   'friends': 57,
#   'create_count': 'Sat Jan 21 19:35:18 +0000 2017'},
#  {'fecha': 'Mon Jan 18 17:02:11 +0000 2021',
#   'texto': 'Hoy la #CaravanaDeLaEsperanza recorrerá el sector Norte de Machala 🚙🚲🛵🚴\n\nNos concentramos a las 18h30 en la Av. Buenavista y Guabo (Esquina) en sentido a la Napoleón Mera\n\nLos esperamos!\n\n#LaPatriaVuelve #ARecuperarElFuturo #TodosSomos1 #ElOroEs1 #OrgulloCorreísta  🇪🇨 https://t.co/bxwgevXzz6',
#   'longuitud': 292,
#   'hashtags': ['CaravanaDeLaEsperanza',
#    'LaPatriaVuelve',
#    'ARecuperarElFuturo',
#    'TodosSomos1',
#    'ElOroEs1',
#    'OrgulloCorreísta'],
#   'num_hashtags': 6,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 25,
#   'name_place': 'Machala',
#   'full_name_place': 'Machala, Ecuador',
#   'country': 'Ecuador',
#   'username': 'CavoZambrano',
#   'followers': 5114,
#   'friends': 522,
#   'create_count': 'Wed Feb 27 16:30:42 +0000 2013'},
#  {'fecha': 'Mon Jan 18 17:02:06 +0000 2021',
#   'texto': 'A una hora de comenzar, estás listo? 💼🚀 https://t.co/57uz66GhOl',
#   'longuitud': 63,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'exponentialset',
#   'followers': 52,
#   'friends': 66,
#   'create_count': 'Wed May 13 01:31:41 +0000 2020'},
#  {'fecha': 'Mon Jan 18 17:01:57 +0000 2021',
#   'texto': '#AtahualpaEsCapacitación 📌El Gobierno Parroquial de Atahualpa extiende la cordial invitación a todos los productores interesados en #capacitarse 👨\u200d🌾 en el Sistema de Participativo de Garantías para Certificación Agroecológica\n\nℹPara mayor información comunícate al\n📞099 2876 328 https://t.co/p65O1bzWjG',
#   'longuitud': 302,
#   'hashtags': ['AtahualpaEsCapacitación', 'capacitarse'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'gad_atahualpa',
#   'followers': 43,
#   'friends': 158,
#   'create_count': 'Mon Jul 10 02:55:25 +0000 2017'},
#  {'fecha': 'Mon Jan 18 17:01:39 +0000 2021',
#   'texto': 'Damos apoyo a quienes dentro de sus garantías individuales son abusados por las autoridades, y orientamos a nuestros clientes en la investigación, problemática, acción e impugnación en litigios constitucionales y administrativos.\nCuenta Conmigo: https://t.co/PfPlVBI25Z https://t.co/ojYpDDJ3PX',
#   'longuitud': 293,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Santo Domingo',
#   'full_name_place': 'Santo Domingo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'StalinNaranjo',
#   'followers': 1574,
#   'friends': 1128,
#   'create_count': 'Sat Oct 17 20:35:31 +0000 2009'},
#  {'fecha': 'Mon Jan 18 17:01:12 +0000 2021',
#   'texto': 'Casi todos los likes a favor de @isidroromero_c en su comentario sobre los venezolanos.  @LaPosta_Ecu #DebatePresidencial2021 #Ecuador https://t.co/h3UTZaK1S9',
#   'longuitud': 158,
#   'hashtags': ['DebatePresidencial2021', 'Ecuador'],
#   'num_hashtags': 2,
#   'mencions': ['isidroromero_c', 'LaPosta_Ecu'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Ecuador',
#   'full_name_place': 'Ecuador',
#   'country': 'Ecuador',
#   'username': 'freddyferruzola',
#   'followers': 1767,
#   'friends': 2308,
#   'create_count': 'Sun Sep 19 03:20:45 +0000 2010'},
#  {'fecha': 'Mon Jan 18 17:00:53 +0000 2021',
#   'texto': '#AndrésCapacidadYFuturo\nSe dará prioridad a mujeres jefas de hogar recordemos que es importante tomar en cuenta que miles de mujeres sostienen a sus hijos e hijas https://t.co/AjLaj8ntOE',
#   'longuitud': 186,
#   'hashtags': ['AndrésCapacidadYFuturo'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'juve_1_5_azuay',
#   'followers': 5094,
#   'friends': 4256,
#   'create_count': 'Tue Mar 15 04:39:57 +0000 2011'},
#  {'fecha': 'Mon Jan 18 17:00:39 +0000 2021',
#   'texto': 'Buscamos para Guayaquil  un asesor/a con experiencia en ventas para servicios de seguridad y transporte',
#   'longuitud': 103,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': '41593773ada44a5',
#   'followers': 152,
#   'friends': 776,
#   'create_count': 'Mon Dec 29 00:07:51 +0000 2014'},
#  {'fecha': 'Mon Jan 18 17:00:24 +0000 2021',
#   'texto': '@titoyepezliut @LoloMino No se debe criminalizar a las mujeres.',
#   'longuitud': 63,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['titoyepezliut', 'LoloMino'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'naturap87',
#   'followers': 307,
#   'friends': 849,
#   'create_count': 'Tue Aug 03 04:28:40 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:59:39 +0000 2021',
#   'texto': '⛰\U0001f7e3¡#CALVAS DICE VLADIMIR A LA ASAMBLEA!💪🏽🚗🚚🚙\U0001f6fb🚜\n\n✌🏽💟 Gracias hermanos de #Cariamanga por su respaldo. Somos la alianza de la juventud, del agricultor, del ganadero,del emprendedor.🧑🏻\u200d🌾🙋🏽\u200d♂️\n\n#VladimirALaAsamblea ✅🗳 #LOJAPrimero \U0001f7e3✌🏽@andrepenacueva @ErickPatinoEC @JohaTorresEc https://t.co/mLOjFA3gdY',
#   'longuitud': 298,
#   'hashtags': ['CALVAS', 'Cariamanga', 'VladimirALaAsamblea', 'LOJAPrimero'],
#   'num_hashtags': 4,
#   'mencions': ['andrepenacueva', 'ErickPatinoEC', 'JohaTorresEc'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Calvas',
#   'full_name_place': 'Calvas, Ecuador',
#   'country': 'Ecuador',
#   'username': 'vladiplacencia',
#   'followers': 1039,
#   'friends': 321,
#   'create_count': 'Mon Apr 13 00:45:57 +0000 2015'},
#  {'fecha': 'Mon Jan 18 16:59:28 +0000 2021',
#   'texto': 'Lo invitamos a nuestro primer evento del 2021, en el cual le mostraremos cómo identificar mercados y expandir el comercio de bienes y contratación de servicios, ubicando asertivamente a potenciales clientes, aliados y proveedores.\nRegistro sin costó aquí👇🏻\nhttps://t.co/FOCGFKkrIN https://t.co/k68PzWyyYo',
#   'longuitud': 304,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'cipemec',
#   'followers': 4668,
#   'friends': 1057,
#   'create_count': 'Mon Jul 08 13:57:34 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:59:11 +0000 2021',
#   'texto': '@GuerreroSimon2 @EtsaAngel @Ileve6 Un burro hablando de orejas, es lo típico solamente una persona que carece de mucho en educación y mínima preparación puede apoyar a un Lelo que representa la época de corrupción más grande el Ecuador donde teniendo todos los recursos para cambiar al país, solo re enriquecieron🤮',
#   'longuitud': 314,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['GuerreroSimon2', 'EtsaAngel', 'Ileve6'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'rogmos',
#   'followers': 84,
#   'friends': 154,
#   'create_count': 'Tue Apr 24 18:23:05 +0000 2012'},
#  {'fecha': 'Mon Jan 18 16:58:06 +0000 2021',
#   'texto': '#CotidianaMenteDolito\nRodando Mejía, estuve en la granja agroecológica Uyumbicho  dialogando con una familia emprendedora, aprendí a preparar biol orgánico. Próximamente  más detalles en mi nuevo video. https://t.co/pBy29k6v8A',
#   'longuitud': 226,
#   'hashtags': ['CotidianaMenteDolito'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Mejia',
#   'full_name_place': 'Mejia, Ecuador',
#   'country': 'Ecuador',
#   'username': 'BuenanoDolito',
#   'followers': 4,
#   'friends': 23,
#   'create_count': 'Sat Aug 29 13:33:36 +0000 2020'},
#  {'fecha': 'Mon Jan 18 16:57:28 +0000 2021',
#   'texto': '#AndrésCapacidadYFuturo\nEntrega de un bono emergente de 1000 dólares a un millón de familias durante la primera semana de Gobierno, como una forma de resarcir el daño que ocasionó la administración del presidente Lenín Moreno al priorizar el capital sobre la vida humana https://t.co/bwjA0Ghj7y',
#   'longuitud': 294,
#   'hashtags': ['AndrésCapacidadYFuturo'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'juve_1_5_azuay',
#   'followers': 5094,
#   'friends': 4256,
#   'create_count': 'Tue Mar 15 04:39:57 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:56:34 +0000 2021',
#   'texto': 'Soñé que Dérek Shepard era el mejor odontologo y era mi mejor amigo y me iba a limar los dientes de adelante para que salga bien en una foto que tenia que tomarme para el hospital JAJAJA',
#   'longuitud': 186,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'DaniGuerrero_C',
#   'followers': 773,
#   'friends': 481,
#   'create_count': 'Sun Oct 02 02:29:53 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:56:02 +0000 2021',
#   'texto': 'Pat Mahomes salió con contusión esta en observación, él y el QuaterBack de los Bills son los jóvenes contra los veteranos de los Packers y los Bucaneros Brady y Rogers, son finales a todo o nada @XavierOZevallos @pablo_serrano88',
#   'longuitud': 228,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['XavierOZevallos', 'pablo_serrano88'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'duval75',
#   'followers': 695,
#   'friends': 4679,
#   'create_count': 'Tue Jun 08 21:16:00 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:55:48 +0000 2021',
#   'texto': '@nila_mora Nosotros Estimada somos los que hacemos Grande a Nuestro País. Ud ha vivido como yo, póngase la Mano  en el Pecho y pregúntese que época de la vida fue la mejor no solo económicamente. Creo que debemos empezar por allí, muchos de nosotros hemos vivido ya otras realidades.',
#   'longuitud': 283,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['nila_mora'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'theomorales',
#   'followers': 2058,
#   'friends': 4273,
#   'create_count': 'Mon Mar 15 16:18:04 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:54:26 +0000 2021',
#   'texto': 'Abanderamos la lucha de los humildes, somos gente como tú, indignados de la clase política tradicional y queremos cambiar la historia de Manabí. \n¡Se puede vencer a grandes chequeras gastando suela y con el apoyo de los indignados!\n\n#VotaPorLa95 \n#BarreLoViejo\n#NuevaGeneración https://t.co/OS5W4UVg8w',
#   'longuitud': 301,
#   'hashtags': ['VotaPorLa95', 'BarreLoViejo', 'NuevaGeneración'],
#   'num_hashtags': 3,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 3,
#   'name_place': 'Portoviejo',
#   'full_name_place': 'Portoviejo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'NGManabi',
#   'followers': 185,
#   'friends': 50,
#   'create_count': 'Thu Sep 13 18:48:51 +0000 2018'},
#  {'fecha': 'Mon Jan 18 16:54:14 +0000 2021',
#   'texto': 'Me avisan que candidatos están a favor del lenguaje inclusivo para no votar por ellos, gracias',
#   'longuitud': 94,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Riobamba',
#   'full_name_place': 'Riobamba, Ecuador',
#   'country': 'Ecuador',
#   'username': 'chelomendez2',
#   'followers': 1459,
#   'friends': 982,
#   'create_count': 'Sat May 07 16:46:21 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:52:35 +0000 2021',
#   'texto': '* Visitando a mi tóxica en el trabajo * https://t.co/g7JrVKkGXx',
#   'longuitud': 63,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Santo Domingo',
#   'full_name_place': 'Santo Domingo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'marco_portnoy',
#   'followers': 585,
#   'friends': 785,
#   'create_count': 'Fri Aug 13 19:32:21 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:52:28 +0000 2021',
#   'texto': 'Ayer los Bucaneros aprovecharon los pases interceptados a Drew Brees, de todos los favoritos pasaron Los Chiefs de Kansas, Lamar una decepcion, Brady primó con su equipo y Rogers de los Packers implacable @XavierOZevallos @pablo_serrano88',
#   'longuitud': 238,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['XavierOZevallos', 'pablo_serrano88'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'duval75',
#   'followers': 695,
#   'friends': 4679,
#   'create_count': 'Tue Jun 08 21:16:00 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:52:25 +0000 2021',
#   'texto': '@ecuadorenvivo La verdad verdad les deseo lo mejor para beneficio del pueblo pero sabiendo la ineptitud de este gobiernos sumado a esto los más vivos de siempre ojalá y no se vuelva un caos..siempre habrá interés de por medio',
#   'longuitud': 225,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuadorenvivo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': '41593773ada44a5',
#   'followers': 152,
#   'friends': 776,
#   'create_count': 'Mon Dec 29 00:07:51 +0000 2014'},
#  {'fecha': 'Mon Jan 18 16:51:48 +0000 2021',
#   'texto': '@alcaldiagye @RiesgosM Frente a Plaza Tia de la Joya, anoche estaba estacionado, sin más ni más, en el parterre un carro. Al parecer era del dueño de la carretilla que está en ese redondel. Cada quien hace lo que quiere y se cree dueño del mundo. Hay necesidad, pero no abusen!!!!!!',
#   'longuitud': 282,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['alcaldiagye', 'RiesgosM'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Daule',
#   'full_name_place': 'Daule, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Marietah64',
#   'followers': 107,
#   'friends': 317,
#   'create_count': 'Fri Feb 04 08:04:28 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:50:51 +0000 2021',
#   'texto': '@luisantonio_r Es mejor que opines de política pero con la verdad, sino lo vas hacer de esa manera la gente te va a dar como bombo en fiesta. Un consejo, Ser imparcial y objetivo no cuesta nada. No caigas en lo que hacen los otros seudo periodistas, en decir mentiras. Acepta el consejo.',
#   'longuitud': 287,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['luisantonio_r'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Valencia',
#   'full_name_place': 'Valencia, Ecuador',
#   'country': 'Ecuador',
#   'username': 'GoverLeonCanto1',
#   'followers': 686,
#   'friends': 907,
#   'create_count': 'Mon Jun 10 01:56:17 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:50:46 +0000 2021',
#   'texto': '#EcuadorDebate2021 Entrega de un bono emergente de 1000 dólares a un millón de familias durante la primera semana de Gobierno, como una forma de resarcir el daño que ocasionó la administración del presidente Lenín Moreno al priorizar el capital sobre la vida humana https://t.co/zvP0v2dYbZ',
#   'longuitud': 289,
#   'hashtags': ['EcuadorDebate2021'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'juve_1_5_azuay',
#   'followers': 5094,
#   'friends': 4256,
#   'create_count': 'Tue Mar 15 04:39:57 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:49:48 +0000 2021',
#   'texto': 'Todo lo que esta hecho a nuestro alrededor fue hecho con energía, para atraer cosas positivas a nuestras vidas, empecemos dando energía positiva.\nExcelente semana!',
#   'longuitud': 163,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'emoreira0506',
#   'followers': 44,
#   'friends': 287,
#   'create_count': 'Thu Jan 10 02:20:38 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:49:40 +0000 2021',
#   'texto': '@DamianCruzG @xhervas A todos bro pero así es el Ecuador, si los pensantes no damos el voto al menos malo, gana el idiota que es el candidato de los rateros!',
#   'longuitud': 157,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['DamianCruzG', 'xhervas'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'YoSoyJoseMartin',
#   'followers': 3083,
#   'friends': 988,
#   'create_count': 'Wed Apr 15 21:06:07 +0000 2009'},
#  {'fecha': 'Mon Jan 18 16:49:09 +0000 2021',
#   'texto': 'algun día me voy a estar riendo de todo esto en un bar de europa LO SE',
#   'longuitud': 70,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Samborondon',
#   'full_name_place': 'Samborondon, Ecuador',
#   'country': 'Ecuador',
#   'username': 'unasangriapls',
#   'followers': 607,
#   'friends': 423,
#   'create_count': 'Tue Nov 09 02:05:10 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:48:33 +0000 2021',
#   'texto': 'Llevo días fuera y a ella no le importa.',
#   'longuitud': 40,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'maevur',
#   'followers': 123,
#   'friends': 98,
#   'create_count': 'Sat Oct 26 02:33:04 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:48:27 +0000 2021',
#   'texto': '@cubalondra lastimosamente no responde a los propósitos de salir del estancamiento que el mismo socialismo nos metió, nos dejaron chiros. Esperemos salir de ellos y visualizar un nuevo futuro. y no llegar a un grave problema como Vnzla, producto de un manual impartido por Fcastro.',
#   'longuitud': 281,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['cubalondra'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Daule',
#   'full_name_place': 'Daule, Ecuador',
#   'country': 'Ecuador',
#   'username': '60b5bcb6d3c14b9',
#   'followers': 6,
#   'friends': 192,
#   'create_count': 'Mon Apr 07 18:42:03 +0000 2014'},
#  {'fecha': 'Mon Jan 18 16:48:10 +0000 2021',
#   'texto': '@EnClavePolitik @MashiRafael @teleSURtv Claro a los rateros por su nombre Correa es robo',
#   'longuitud': 88,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['EnClavePolitik', 'MashiRafael', 'teleSURtv'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Santa Elena',
#   'full_name_place': 'Santa Elena, Ecuador',
#   'country': 'Ecuador',
#   'username': 'RicardoCanabico',
#   'followers': 19532,
#   'friends': 13912,
#   'create_count': 'Sat Aug 24 15:29:49 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:47:43 +0000 2021',
#   'texto': 'Lunes 18/enero, premiamos a los ganadores del concurso de fotografía “Mi selva, tu destino”.\n\nCATEGORÍA AFICIONADOS\n1. Dunio Chiriap\n2. Katerin Jaramillo\n3. Jean Carlo Merino\n\nCATEGORIA PROFESIONAL\n1. Wilson Cabrera Guartazaca\n2. Paúl González\n3. Joel Montenegro https://t.co/LmKzllBgdO',
#   'longuitud': 286,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'name_place': 'Morona',
#   'full_name_place': 'Morona, Ecuador',
#   'country': 'Ecuador',
#   'username': 'PrefecturaMS',
#   'followers': 2397,
#   'friends': 741,
#   'create_count': 'Fri Jun 22 19:40:15 +0000 2012'},
#  {'fecha': 'Mon Jan 18 16:47:42 +0000 2021',
#   'texto': '@folalla2002 @CarlosVerareal Pero para ser “Presidente del Ecuador”tiene que saber de cualquier tema pues , tiene que estar bien preparado yo también no estoy a favor de nadie pero por favor que sea gente calificada para este cargo .........que esperamos entonces de quien nos gobierne ???',
#   'longuitud': 289,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['folalla2002', 'CarlosVerareal'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Loja',
#   'full_name_place': 'Loja, Ecuador',
#   'country': 'Ecuador',
#   'username': 'j_naula',
#   'followers': 26,
#   'friends': 85,
#   'create_count': 'Fri Nov 22 12:26:18 +0000 2013'},
#  {'fecha': 'Mon Jan 18 16:47:21 +0000 2021',
#   'texto': 'A propósito dé precisiones @LuzLateraL ahora resulta que llegan solo 15k y que llegaron en tandas de ese número hasta completar 86k (no diré nada de que no sean múltiplos). Ya parece el cacho del gallogato...',
#   'longuitud': 208,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['LuzLateraL'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'jpanchog',
#   'followers': 306,
#   'friends': 242,
#   'create_count': 'Tue Aug 21 16:29:55 +0000 2007'},
#  {'fecha': 'Mon Jan 18 16:46:02 +0000 2021',
#   'texto': '@nila_mora Un cambio para bien🤔, Nebot hace unos meses buscaba al verdadero Guillermo, Arauz y joven aparecido, Lucio viviendo de correa, Yaku en otro planeta.\nEn realidad esperaríamos algo bueno de éstos?? Lo dudo, solo tenemos que trabajar día a día es lo que queda.',
#   'longuitud': 268,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['nila_mora'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'theomorales',
#   'followers': 2058,
#   'friends': 4273,
#   'create_count': 'Mon Mar 15 16:18:04 +0000 2010'},
#  {'fecha': 'Mon Jan 18 16:45:47 +0000 2021',
#   'texto': 'A un líder no se lo define.A un líder se le reconoce .',
#   'longuitud': 54,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'ProanoMaya',
#   'followers': 1825,
#   'friends': 2,
#   'create_count': 'Sun Nov 25 22:44:26 +0000 2012'},
#  {'fecha': 'Mon Jan 18 16:45:38 +0000 2021',
#   'texto': '@jpjaramillo25 @jfcardenasg @ecuadorverifica @GKecuador Es una de las tantas patrañas como los supuestos sobreprecios en las obras, refinería del pacifico, etc que pese a contraloria y fiscalia adhoc en casi 4 años no determinan responsabilidades de contratistas, administradores, fiscalizadores, etc',
#   'longuitud': 300,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['jpjaramillo25', 'jfcardenasg', 'ecuadorverifica', 'GKecuador'],
#   'num_mencions': 4,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 1,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'geochambers',
#   'followers': 204,
#   'friends': 211,
#   'create_count': 'Thu Mar 24 21:50:02 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:44:52 +0000 2021',
#   'texto': 'A 2 días del 20 de enero, Donald Trump publica esto en Telegram... https://t.co/4m0Wmqpp8m',
#   'longuitud': 90,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'JuanGraDel',
#   'followers': 910,
#   'friends': 5047,
#   'create_count': 'Mon Jan 03 02:52:24 +0000 2011'},
#  {'fecha': 'Mon Jan 18 16:44:27 +0000 2021',
#   'texto': 'Era de inocentes creer que este gobierno iba a cumplir! https://t.co/4rWXbtW19X',
#   'longuitud': 79,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'MariaAdrianaT',
#   'followers': 969,
#   'friends': 1633,
#   'create_count': 'Tue Jun 26 20:15:07 +0000 2012'},
#  {'fecha': 'Mon Jan 18 16:43:55 +0000 2021',
#   'texto': 'Arauz vive en el futuro, quiere recuperarlo a como dé lugar, aunque el futuro aún no existe; es decir que vive de la fábula, como un niño, cautivado por Alicia en el país de las maravillas. Me recuerda a Correa, que en plena crisis de Angostura (2008) leía #HarryPotter. https://t.co/xibkFPKdFo',
#   'longuitud': 294,
#   'hashtags': ['HarryPotter'],
#   'num_hashtags': 1,
# ...
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'aesteban_10',
#   'followers': 62,
#   'friends': 186,
#   'create_count': 'Sun Jul 31 21:36:26 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:46:18 +0000 2021',
#   'texto': '#DebatePresidencial2021 #DebateEnPijamas \nA "cuartos de final": Freile, Celi, Montufar, Carrasco, Almeida, Hervas, Lasso, Perez y Arauz.\n\nSe quedan en "fase de grupos"\nLarrea, Velasco, Peña, Romero, Gutierrez, Sagnay y Andrade ( los dos últimos con 0 puntos y goleados)',
#   'longuitud': 269,
#   'hashtags': ['DebatePresidencial2021', 'DebateEnPijamas'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'santibeneno',
#   'followers': 639,
#   'friends': 1002,
#   'create_count': 'Thu Nov 18 17:08:41 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:45:10 +0000 2021',
#   'texto': '@CesarMontufar51\n#CesarMontufar\n\n"El endurecimiento de penas no resuelve la violencia. El Ecuador debe avanzar a ser una sociedad de paz para amarnos los unos a los otros"\n\n#DebatePresidencial2021',
#   'longuitud': 196,
#   'hashtags': ['CesarMontufar', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['CesarMontufar51'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Santo Domingo',
#   'full_name_place': 'Santo Domingo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Cevallosangela',
#   'followers': 1224,
#   'friends': 1538,
#   'create_count': 'Sat Oct 09 04:40:10 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:44:53 +0000 2021',
#   'texto': 'Los torpes candidotes creen que DIFAMANDO van a lograr votos.',
#   'longuitud': 61,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Duran',
#   'full_name_place': 'Duran, Ecuador',
#   'country': 'Ecuador',
#   'username': 'galo_s',
#   'followers': 68,
#   'friends': 146,
#   'create_count': 'Fri Aug 05 19:39:17 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:44:44 +0000 2021',
#   'texto': 'Just posted a photo @ Salinas, Ecuador https://t.co/i5Qn7xy9pW',
#   'longuitud': 62,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'en',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Salinas',
#   'full_name_place': 'Salinas, Ecuador',
#   'country': 'Ecuador',
#   'username': 'DannyByrd09',
#   'followers': 309,
#   'friends': 403,
#   'create_count': 'Sun Oct 05 17:43:54 +0000 2014'},
#  {'fecha': 'Mon Jan 18 03:44:30 +0000 2021',
#   'texto': 'Lasso: Vamos a firmar tratados de libre comercio porque quiero comprarme el iphone nuevo y aquí sale muy caro. \n#DebatePresidencial',
#   'longuitud': 131,
#   'hashtags': ['DebatePresidencial'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'name_place': 'Latacunga',
#   'full_name_place': 'Latacunga, Ecuador',
#   'country': 'Ecuador',
#   'username': 'morcevp',
#   'followers': 45,
#   'friends': 172,
#   'create_count': 'Wed Apr 01 06:35:30 +0000 2015'},
#  {'fecha': 'Mon Jan 18 03:44:17 +0000 2021',
#   'texto': '"Sonrie..., eso molesta a la gente que no te quiere"',
#   'longuitud': 52,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'BraCas94',
#   'followers': 487,
#   'friends': 51,
#   'create_count': 'Thu Mar 17 21:11:39 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:44:15 +0000 2021',
#   'texto': 'Tengo 3 candidatos por los que  me parece yo votaría,  pero uno en especial habla con la seguridad y presencia internacional que necesita este país, creo q irá a 2da vuelta con mi voto 🇪🇨 #Elecciones2021 #DebatePresidencial',
#   'longuitud': 223,
#   'hashtags': ['Elecciones2021', 'DebatePresidencial'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': 'Portoviejo',
#   'full_name_place': 'Portoviejo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'JgEcuador',
#   'followers': 11880,
#   'friends': 1561,
#   'create_count': 'Thu Feb 25 21:45:42 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:43:40 +0000 2021',
#   'texto': 'Buen cierre de Hervas en torno a un tema vergonzoso para el país: embarazo juvenil y violencia de género. Este tema debe ser una prioridad.',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 26,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'nicolasrmunoz',
#   'followers': 6309,
#   'friends': 194,
#   'create_count': 'Wed Apr 28 20:49:36 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:43:36 +0000 2021',
#   'texto': 'Lo veo a este candidato y lo primero que se me viene a la cabeza es la viuda en patineta. \nYa no es culpa 😒 https://t.co/mB2XG1bznD',
#   'longuitud': 131,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 12,
#   'favorite_count': 46,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'ivonnelago',
#   'followers': 19426,
#   'friends': 1707,
#   'create_count': 'Wed Apr 14 23:21:15 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:43:29 +0000 2021',
#   'texto': '#GuillermoLasso\n@LassoGuillermo \n\n"La flora ecuatoriana entró a los Estados Unidos con el 8% de arancel, mientras que Colombia 0%. Hay que abrir mercados"\n\n#DebatePresidencial2021',
#   'longuitud': 179,
#   'hashtags': ['GuillermoLasso', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['LassoGuillermo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Santo Domingo',
#   'full_name_place': 'Santo Domingo, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Cevallosangela',
#   'followers': 1224,
#   'friends': 1538,
#   'create_count': 'Sat Oct 09 04:40:10 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:43:20 +0000 2021',
#   'texto': 'Eso! No es lo mejor que tenemos pero es el deber de informarnos. Series, deportes y demás pasan a segundo plano. Es importante estar informado. https://t.co/vT0vYC1ETr',
#   'longuitud': 167,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 2,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'johnnyugcha',
#   'followers': 883,
#   'friends': 2477,
#   'create_count': 'Sat Oct 02 12:36:08 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:43:08 +0000 2021',
#   'texto': '⚜CUSTODIO DE VALORES 👉🏼Estamos comprometidos con tu seguridad🛡🤵🏻\nNuestro objetivo es brindar un servicio de seguridad profesional🦸🏻\u200d♂️, contamos con tecnologías de última generación🔫 y personal altamente capacitado🤵🏻🇪🇨 para el traslado de tus bienes a cualquier provincia del país https://t.co/pMzotB3ca2',
#   'longuitud': 304,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'gygescoltas',
#   'followers': 16,
#   'friends': 223,
#   'create_count': 'Thu Sep 08 10:04:25 +0000 2016'},
#  {'fecha': 'Mon Jan 18 03:42:49 +0000 2021',
#   'texto': '#PorQueVotoPorArauz porque gracias a las políticas de la RC se democrátizo el acceso a la universidad pública, pudiendo acceder a una educación superior, gratuita y de calidad!!! https://t.co/3uBz52LzBT',
#   'longuitud': 202,
#   'hashtags': ['PorQueVotoPorArauz'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 4,
#   'name_place': 'Cuenca',
#   'full_name_place': 'Cuenca, Ecuador',
#   'country': 'Ecuador',
#   'username': 'DiegoChablay',
#   'followers': 620,
#   'friends': 4133,
#   'create_count': 'Thu Jul 21 02:47:38 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:42:31 +0000 2021',
#   'texto': 'Una política internacional 360 apertura comercial con todos con protección a los sectores más sensibles\nUn Ecuador Agro exportador y Agroindustrializado que genere recursos para sostener la dolarizacion\nSubir nuestras exportaciones\n#GustavoLarreaPresidente',
#   'longuitud': 256,
#   'hashtags': ['GustavoLarreaPresidente'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 6,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'aperaltamarin',
#   'followers': 651,
#   'friends': 195,
#   'create_count': 'Mon Jun 24 20:48:21 +0000 2019'},
#  {'fecha': 'Mon Jan 18 03:42:27 +0000 2021',
#   'texto': 'Yo quiero saber q clase de droga se mete Lucio Gutiérrez para ir a cada debate. El jura q el país era una maravilla y éramos potencia mundial en su gobierno, y que nunca salió huyendo en un helicóptero y q todos lo amamos x ser el mejor presidente del Ecuador 🤡',
#   'longuitud': 261,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'Michdelsalto',
#   'followers': 62,
#   'friends': 251,
#   'create_count': 'Sun Mar 01 23:07:00 +0000 2020'},
#  {'fecha': 'Mon Jan 18 03:42:09 +0000 2021',
#   'texto': '📶ESCOLTAS PROFESIONALES DEL ECUADOR G&amp;G👨🏻\u200d💼\n\n📌Nuestro objetivo es brindar un servicio de seguridad profesional a nuestros clientes \n📌Diseñar y organizar sistemas de protección adecuada a cada situación en particular\n📌Contar con un personal de seguridad capacitado . https://t.co/hhspffoj3M',
#   'longuitud': 293,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'gygescoltas',
#   'followers': 16,
#   'friends': 223,
#   'create_count': 'Thu Sep 08 10:04:25 +0000 2016'},
#  {'fecha': 'Mon Jan 18 03:41:50 +0000 2021',
#   'texto': 'Grandes palabras de Hervas. Una cachetada con pañuelo blanco a esos asquerosos.',
#   'longuitud': 79,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 13,
#   'favorite_count': 51,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'abelopunk',
#   'followers': 1690,
#   'friends': 341,
#   'create_count': 'Sun Jul 04 17:06:43 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:41:42 +0000 2021',
#   'texto': 'Junto a @andreaarroyo23 y todos los #AsambleístasDelCAMBIO impulsaremos una ley que apoye y vele por una atención de calidad a pacientes oncológicos.\n\n#PropuestasDeLasso\n#LassoEsElCambio\n#LassoEsLaOpción\n#LassoPresidente2021',
#   'longuitud': 224,
#   'hashtags': ['AsambleístasDelCAMBIO',
#    'PropuestasDeLasso',
#    'LassoEsElCambio',
#    'LassoEsLaOpción',
#    'LassoPresidente2021'],
#   'num_hashtags': 5,
#   'mencions': ['andreaarroyo23'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 34,
#   'name_place': 'Loja',
#   'full_name_place': 'Loja, Ecuador',
#   'country': 'Ecuador',
#   'username': 'ABorreroVega',
#   'followers': 7754,
#   'friends': 462,
#   'create_count': 'Tue Jun 16 21:21:16 +0000 2015'},
#  {'fecha': 'Mon Jan 18 03:41:34 +0000 2021',
#   'texto': '@xhervas dando cátedra a los demás candidatos en temas de #ddhh. Sabe lo que dice y su plan lo demuestra! \n#XavierHervasPresidente\n#DebatePresidencial2021',
#   'longuitud': 154,
#   'hashtags': ['ddhh', 'XavierHervasPresidente', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['xhervas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 3,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'CrisFlopu',
#   'followers': 427,
#   'friends': 882,
#   'create_count': 'Fri Mar 11 22:15:35 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:41:27 +0000 2021',
#   'texto': 'Este es el nivel de debate “El primer día de mi gobierno me pegaré una borrachera del carajo y el segundo día meteremos gente a la cárcel" Isidro Romero @isidroromero_c',
#   'longuitud': 168,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['isidroromero_c'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': 'Riobamba',
#   'full_name_place': 'Riobamba, Ecuador',
#   'country': 'Ecuador',
#   'username': 'juankp25',
#   'followers': 234,
#   'friends': 424,
#   'create_count': 'Sun Dec 12 17:08:59 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:41:16 +0000 2021',
#   'texto': 'Hervas es el segundo candidato en este debate que hace alusión directa de la necesidad de proteger a los grupos LGBTI y habla de un “Estado fallido” y reprocha la violencia de género y maternidad infantil',
#   'longuitud': 204,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 14,
#   'favorite_count': 32,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'fredylobato',
#   'followers': 3381,
#   'friends': 2203,
#   'create_count': 'Wed Jun 01 18:44:19 +0000 2011'},
#  {'fecha': 'Mon Jan 18 03:41:15 +0000 2021',
#   'texto': 'en estos momentos le extraño a mi Ñaño, mi compañero de fútbol... él me hizo de Boca 💙💛💙',
#   'longuitud': 88,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'soffidelaU',
#   'followers': 2963,
#   'friends': 936,
#   'create_count': 'Tue Aug 03 04:57:23 +0000 2010'},
#  {'fecha': 'Mon Jan 18 03:41:01 +0000 2021',
#   'texto': '@AlexitaRosero @MashiRafael No se si genio, pero tengo la suficiente inteligencia, pero sobretodo criterio, dignidad y amor propio, como para no votar por un Lelo que desde ahorita demuestra ser un imbecil a tiempo completo y un pobre inepto, y sólo un tarado igual a el le daría el voto',
#   'longuitud': 287,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['AlexitaRosero', 'MashiRafael'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'flaca0404',
#   'followers': 652,
#   'friends': 911,
#   'create_count': 'Thu Sep 03 03:13:44 +0000 2015'},
#  {'fecha': 'Mon Jan 18 03:41:01 +0000 2021',
#   'texto': '@karennunezr Porque la gente dice: voy a votar por Arauz porque Correa hizo esto, simplemente eso',
#   'longuitud': 97,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['karennunezr'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Quito',
#   'full_name_place': 'Quito, Ecuador',
#   'country': 'Ecuador',
#   'username': 'KevinDavidQ',
#   'followers': 149,
#   'friends': 390,
#   'create_count': 'Wed Aug 01 00:40:59 +0000 2012'},
#  {'fecha': 'Mon Jan 18 03:40:48 +0000 2021',
#   'texto': '@MiguelAngelTo Pero como vas a sacar 30 publicaciones diarias de los goles que mete entrenando? ESTÁ ENTRENANDO!!!!',
#   'longuitud': 115,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['MiguelAngelTo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': 'Guayaquil',
#   'full_name_place': 'Guayaquil, Ecuador',
#   'country': 'Ecuador',
#   'username': 'iandradetorres',
#   'followers': 295,
#   'friends': 1049,
#   'create_count': 'Thu Mar 09 22:55:30 +0000 2017'}]

# %%
len(tweets_apis)
# Out:
# 1000
