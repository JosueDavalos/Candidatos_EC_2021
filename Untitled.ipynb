# %%
# snscrape twitter-search "corona since:2019-12-31 until:2020-09-25" > borrar.txt
import json
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import numpy as np
import pandas as pd

consumer_key = "UMqWhrvhnvlriQjUGsEdeFBun"
consumer_secret = "wKqdKBJsntpqd03EmPEMfyMf4FZnGF05RbF2oG80MxgMAr9Kui"
access_token = "229639629-yXLcOQJlI9U8f6qqCStZtufUv9x3b2wqpwwdLsqW"
access_token_secret = "rggSaGyuw6TOtfdg0tQsuXQAZdq6SIApeB5vs6Shv9wry"

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token , access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
def get_data(data): 
    return json.dumps(data._json, indent=2, ensure_ascii=False)

def get_data_Json(data):
    return data._json

def menciones(list):
    menciones = []
    for dic_mencion in list:
        mencion = dic_mencion['screen_name']
        menciones.append(mencion)
    return menciones

def get_hashtags(list_dic):
    l = []
    for dic_hashtag in list_dic:
        l.append(dic_hashtag['text'])
    return l

def diccionario_tw (tw):
    dic = {}
    dic["fecha"] = tw['created_at']
    dic["texto"] = tw['full_text']
    dic["longuitud"] = len( dic["texto"])
    dic_entity = tw['entities']
    list_hashtags = get_hashtags(dic_entity['hashtags'])
    dic["hashtags"] = list_hashtags
    dic["num_hashtags"] = len(list_hashtags)
    dic["mencions"] = menciones(dic_entity['user_mentions'])
    dic["num_mencions"] = len(menciones(dic_entity['user_mentions']))
    dic['language'] = tw['lang']
    dic['retweet_count'] = tw['retweet_count']
    dic['favorite_count'] = tw['favorite_count']
    
    dic_place = tw['place']
    if dic_place is not None:
        dic['name_place'] = dic_place['name']
        dic['full_name_place'] = dic_place['full_name']
        dic['country'] = dic_place['country']
    else:
        dic['name_place'] = np.nan
        dic['full_name_place'] = np.nan
        dic['country'] = np.nan



    dic_user = tw['user']
    dic["username"] = dic_user['screen_name']
    dic["followers"] = dic_user['followers_count']
    dic["friends"] = dic_user['friends_count']
    dic["create_count"] = dic_user['created_at']

    return dic



def get_info_tweets(list_of_tweet):
    lista_tweets = []
    for tweet in list_of_tweet:
        tw = get_data_Json(tweet)
        dicc = diccionario_tw(tw)
        lista_tweets.append(dicc)
    return lista_tweets




def get_tweets_from_tweepy(keywords=[], hashtags=[], mencions=[], fecha_inicio=None, fecha_fin=None, country='',
                          min_replies=None, min_faves=None, min_retweets=None, username=None, language=None,
                          min_hashtags=None, min_mencions=None, fecha_min_creation_user=None, fecha_max_creation_user=None,
                          min_followers=None, min_friends=None, len_min_tweet=None):
    filters = ''

    if  country!='':
        country_id = api.geo_search(query=country, granularity="country")[0].id
        filters += 'place:%s ' %country_id
    if min_replies is not None and min_replies!='':
        filters += 'min_replies:%d ' %min_replies
    if min_faves is not None and min_faves!='':
        filters += 'min_faves:%d ' %min_faves
    if min_retweets is not None and min_retweets!='':
        filters += 'min_retweets:%d ' %min_retweets
    if username is not None and username!='':
        filters += 'from:%s ' %username

    hashtags = ['#'+x for x in hashtags]
    mencions = ['@'+x for x in mencions]
    keywords = ' OR '.join(keywords+hashtags+mencions)

    new_tweets = tweepy.Cursor(api.search, 
                               q='(%s) %s' % (keywords, filters), 
                               since = fecha_inicio,
                               until = fecha_fin,
                               tweet_mode='extended',
                               include_entities=True,
                               count=100,
                               lang=language,
                               ).items(99999999999999)

    return get_info_tweets(list(new_tweets))  #Convert  list of Tweepy's tweets into list of info requierer 

from datetime import timedelta 

def get_DataFrame(tweets, filtros=None):
    if len(tweets)==0:
        return None
    df = pd.DataFrame(tweets)
    df['fecha'] = pd.to_datetime(df['fecha']) - timedelta(hours=5)  
    df['create_count'] = pd.to_datetime(df['create_count'])
    df.set_index('fecha', inplace=True)

    return df

# %%
tweets_apis = get_tweets_from_tweepy(hashtags=['debatepresidencial2021'])
tweets_apis
# Out:
# Rate limit reached. Sleeping for: 488
# Rate limit reached. Sleeping for: 674
# Rate limit reached. Sleeping for: 680
# Rate limit reached. Sleeping for: 675
# [{'fecha': 'Mon Jan 25 03:55:37 +0000 2021',
#   'texto': 'RT @cicloviagye: 1 bicicleta &gt; economía ecuatoriana\n\n #DebatePresidencial2021',
#   'longuitud': 80,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['cicloviagye'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'caritoloitu',
#   'followers': 7,
#   'friends': 65,
#   'create_count': 'Thu Dec 31 17:41:58 +0000 2020'},
#  {'fecha': 'Mon Jan 25 02:57:22 +0000 2021',
#   'texto': 'RT @ecuarauz: En 2015 me comprometí, por mi hijo, que lucharía para que el país no vuelva al pasado oprobioso. Cumplí y millones de ecuator…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1339,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'royrichard20051',
#   'followers': 378,
#   'friends': 287,
#   'create_count': 'Wed Nov 21 15:52:08 +0000 2012'},
#  {'fecha': 'Mon Jan 25 02:46:55 +0000 2021',
#   'texto': 'RT @64W48: Lasso una vez mas hablando del pasado él fue parte de:\n1995: Gobierno de Sixto\n1998: Gobierno de Mahuad\n2000: Gobierno de Gustav…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['64W48'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'NiBurro',
#   'followers': 0,
#   'friends': 14,
#   'create_count': 'Tue Jan 05 16:22:12 +0000 2021'},
#  {'fecha': 'Mon Jan 25 02:27:04 +0000 2021',
#   'texto': 'RT @DamianR1991: Interesante análisis del #DebatePresidencial2021 utilizando #socialnetworks.',
#   'longuitud': 93,
#   'hashtags': ['DebatePresidencial2021', 'socialnetworks'],
#   'num_hashtags': 2,
#   'mencions': ['DamianR1991'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'TejadaRommel',
#   'followers': 120,
#   'friends': 496,
#   'create_count': 'Thu Mar 13 01:35:17 +0000 2014'},
#  {'fecha': 'Mon Jan 25 01:47:29 +0000 2021',
#   'texto': 'RT @yakuperezg: Además en la Consulta Popular preguntaremos a los ecuatorianos si están de acuerdo en la reducción de asambleístas. \n\n#Yaku…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 34,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'kamizvlog',
#   'followers': 1065,
#   'friends': 2322,
#   'create_count': 'Sun Nov 13 20:33:37 +0000 2011'},
#  {'fecha': 'Mon Jan 25 01:35:01 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Vanesa_110452',
#   'followers': 36,
#   'friends': 24,
#   'create_count': 'Tue Nov 20 03:27:20 +0000 2018'},
#  {'fecha': 'Mon Jan 25 01:05:28 +0000 2021',
#   'texto': 'RT @CodigoVidrioEc: ¿Por qué el @cnegobec cambió a último momento el formato del #DebatePresidencial2021? \nEste es el testimonio del period…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['CodigoVidrioEc', 'cnegobec'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'MopaZambrano',
#   'followers': 1130,
#   'friends': 3599,
#   'create_count': 'Fri Mar 22 21:36:33 +0000 2019'},
#  {'fecha': 'Mon Jan 25 01:00:54 +0000 2021',
#   'texto': 'RT @NuriaButina: CONTUNDENTE!!! A alguien le queda alguna duda de que @ecuarauz será el FUTURO PRESIDENTE DEL ECUADOR!!!      @MashiRafael…',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['NuriaButina', 'ecuarauz', 'MashiRafael'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 553,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Angeles10035',
#   'followers': 8478,
#   'friends': 1687,
#   'create_count': 'Mon Sep 26 03:20:31 +0000 2016'},
#  {'fecha': 'Mon Jan 25 01:00:47 +0000 2021',
#   'texto': 'RT @luly_alban: #DebatePresidencial2021 el ganador es #Correa .\nNo lo pueden olvidar a cada rato lo nombran los traumados y sacan a lucir s…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'Correa'],
#   'num_hashtags': 2,
#   'mencions': ['luly_alban'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 284,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Angeles10035',
#   'followers': 8478,
#   'friends': 1687,
#   'create_count': 'Mon Sep 26 03:20:31 +0000 2016'},
#  {'fecha': 'Mon Jan 25 00:56:23 +0000 2021',
#   'texto': 'RT @DamianR1991: Interesante análisis del #DebatePresidencial2021 utilizando #socialnetworks.',
#   'longuitud': 93,
#   'hashtags': ['DebatePresidencial2021', 'socialnetworks'],
#   'num_hashtags': 2,
#   'mencions': ['DamianR1991'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'silviaflor077',
#   'followers': 132,
#   'friends': 307,
#   'create_count': 'Sun Aug 04 01:56:35 +0000 2013'},
#  {'fecha': 'Mon Jan 25 00:44:55 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate\n#DebatePresidencial2021 https://t.co/ovsYlo1fV5',
#   'longuitud': 83,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 27,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:51 +0000 2021',
#   'texto': 'RT @yakuperezg: Vamos a eliminar el Impuesto a la Salida de Divisas y a quienes vienen a invertir del extranjero les exoneraremos el pago d…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 38,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:44 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate\n#DebatePresidencial2021 https://t.co/YrpEzx4gAE',
#   'longuitud': 83,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:35 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate\n#DebatePresidencial2021 https://t.co/jctkjtVJBB',
#   'longuitud': 83,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 36,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:30 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate\n#DebatePresidencial2021 https://t.co/bDE4z9F6FD',
#   'longuitud': 83,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:16 +0000 2021',
#   'texto': 'RT @yakuperezg: Yo he estado con los jóvenes luchando en las calles en contra del examen de admisión Ser Bachiller, por eso tengo la autori…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 96,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:11 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/CLEkiLiOUo',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 17,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:44:04 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/DMBZzLuqYK',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 49,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:43:38 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/f4wroblDNo',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:43:33 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/7XAyNK8hEC',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 23,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:43:27 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/27g0vne1HO',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 40,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:43:20 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#DebatePresidencial2021 https://t.co/qywMfKl9ak',
#   'longuitud': 84,
#   'hashtags': ['YakuClaroQueDebate', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:34 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate\n#Yaku\n#DebatePresidencial2021 https://t.co/XsIWSTLWAX',
#   'longuitud': 89,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 38,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:29 +0000 2021',
#   'texto': 'RT @yakuperezg: Que no se repita lo de la Refinería del Pacífico, 1.500 millones de dólares se hicieron humo, incluso vino el expresidente…',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 72,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:22 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/dTi7GCwiWe',
#   'longuitud': 90,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:17 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/AbxEoiF4tc',
#   'longuitud': 90,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:12 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/6tPdKhv3xQ',
#   'longuitud': 90,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:42:01 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/fIZtr0LGgA',
#   'longuitud': 90,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 30,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:41:56 +0000 2021',
#   'texto': 'RT @yakuperezg: #YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/8FtXndWCoF',
#   'longuitud': 90,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:41:50 +0000 2021',
#   'texto': 'RT @yakuperezg: Los ecuatorianos honestos les ganaremos a los corruptos.\n\n#YakuClaroQueDebate \n#Yaku\n#DebatePresidencial2021 https://t.co/u…',
#   'longuitud': 140,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 19,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:41:44 +0000 2021',
#   'texto': 'RT @yakuperezg: Nosotros tenemos nuestras manos limpias.\n\n#YakuClaroQueDebate \n#Yaku \n#DebatePresidencial2021 https://t.co/Cex0Rp1pCf',
#   'longuitud': 133,
#   'hashtags': ['YakuClaroQueDebate', 'Yaku', 'DebatePresidencial2021'],
#   'num_hashtags': 3,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:40:57 +0000 2021',
#   'texto': 'RT @yakuperezg: Además en la Consulta Popular preguntaremos a los ecuatorianos si están de acuerdo en la reducción de asambleístas. \n\n#Yaku…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['yakuperezg'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 34,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Luis_A_Guingla',
#   'followers': 770,
#   'friends': 4385,
#   'create_count': 'Mon Mar 26 14:54:29 +0000 2012'},
#  {'fecha': 'Mon Jan 25 00:39:13 +0000 2021',
#   'texto': 'RT @JulianMaciasT: He analizado los más de 80.000 tuits lanzados con el HT #DebatePresidencial2021 que fue TT1 durante las dos jornadas del…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['JulianMaciasT'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 695,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'FernandaCamino',
#   'followers': 1071,
#   'friends': 265,
#   'create_count': 'Sun Apr 05 17:22:33 +0000 2009'},
#  {'fecha': 'Mon Jan 25 00:24:14 +0000 2021',
#   'texto': 'RT @EcuatorianoUni2: Nosotros entendemos que en este tiempo tenemos que aplicar la Ética, por eso nosotros establecemos el Pragmatismo Étic…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['EcuatorianoUni2'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AndreaN70014855',
#   'followers': 14,
#   'friends': 91,
#   'create_count': 'Thu Dec 10 21:36:24 +0000 2020'},
#  {'fecha': 'Mon Jan 25 00:03:06 +0000 2021',
#   'texto': 'Seguimos con las Fichas Técnicas sobre los candidatos a la presidencia, esta vez es el turno del candidato a la presidencia Gustavo Larrea \n#Elecciones2021Ec  #DebatePresidencial2021 \nPlan de gobierno completo cortesía de diario El Comercio:\nhttps://t.co/rvODCfw1xK https://t.co/m6UQxopIHX',
#   'longuitud': 289,
#   'hashtags': ['Elecciones2021Ec', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'jonatan1100',
#   'followers': 11,
#   'friends': 142,
#   'create_count': 'Sat Nov 30 22:18:01 +0000 2013'},
#  {'fecha': 'Sun Jan 24 23:43:44 +0000 2021',
#   'texto': 'RT @VamosGuillermo: Este segundo día de #DebatePresidencial2021 nos deja claro, una vez más que Lasso es el más capaz para gobernar. Queda…',
#   'longuitud': 139,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['VamosGuillermo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 120,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'alexchambass',
#   'followers': 241,
#   'friends': 1068,
#   'create_count': 'Tue Apr 26 18:05:50 +0000 2016'},
#  {'fecha': 'Sun Jan 24 23:16:11 +0000 2021',
#   'texto': 'RT @DamianR1991: Interesante análisis del #DebatePresidencial2021 utilizando #socialnetworks.',
#   'longuitud': 93,
#   'hashtags': ['DebatePresidencial2021', 'socialnetworks'],
#   'num_hashtags': 2,
#   'mencions': ['DamianR1991'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'GARodriguezF',
#   'followers': 165,
#   'friends': 547,
#   'create_count': 'Tue Mar 06 01:39:59 +0000 2012'},
#  {'fecha': 'Sun Jan 24 23:10:52 +0000 2021',
#   'texto': 'RT @AnalyticsDarm: ¿Cómo interactuaron los usuarios de twitter con el hashtag #DebatePresidencial2021? En el hilo a continuación te lo expl…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['AnalyticsDarm'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AndreaE211',
#   'followers': 89,
#   'friends': 195,
#   'create_count': 'Thu Aug 26 18:20:08 +0000 2010'},
#  {'fecha': 'Sun Jan 24 23:09:58 +0000 2021',
#   'texto': 'RT @AnalyticsDarm: ¿Cómo interactuaron los usuarios de twitter con el hashtag #DebatePresidencial2021? En el hilo a continuación te lo expl…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['AnalyticsDarm'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'rmarlon308',
#   'followers': 33,
#   'friends': 190,
#   'create_count': 'Mon Jun 02 23:33:13 +0000 2014'},
#  {'fecha': 'Sun Jan 24 23:09:18 +0000 2021',
#   'texto': 'Por otro lado, en el #socialnetwork se pueden identificar cliques. Los cliques  son subconjuntos de una red en la que los actores están más estrecha e intensamente vinculados entre sí. Algunos de los cliques identificados en el #DebatePresidencial2021 son: https://t.co/F90gJqU3nF',
#   'longuitud': 280,
#   'hashtags': ['socialnetwork', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AnalyticsDarm',
#   'followers': 9,
#   'friends': 9,
#   'create_count': 'Thu Oct 01 16:03:48 +0000 2020'},
#  {'fecha': 'Sun Jan 24 23:09:15 +0000 2021',
#   'texto': 'Según esta medida los actores más significativos del #DebatePresidencial2021 , ordenados según el nivel de importancia, fueron los siguientes: https://t.co/0Sal5fakGW',
#   'longuitud': 166,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AnalyticsDarm',
#   'followers': 9,
#   'friends': 9,
#   'create_count': 'Thu Oct 01 16:03:48 +0000 2020'},
#  {'fecha': 'Sun Jan 24 23:09:14 +0000 2021',
#   'texto': '¿Cómo interactuaron los usuarios de twitter con el hashtag #DebatePresidencial2021? En el hilo a continuación te lo explicamos mediante #socialnetworkanalysis. Visita nuestra aplicación https://t.co/GZT9QOIJ7F o presta atención al siguiente HILO: https://t.co/16M9boZN2x',
#   'longuitud': 270,
#   'hashtags': ['DebatePresidencial2021', 'socialnetworkanalysis'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 2,
#   'favorite_count': 4,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AnalyticsDarm',
#   'followers': 9,
#   'friends': 9,
#   'create_count': 'Thu Oct 01 16:03:48 +0000 2020'},
#  {'fecha': 'Sun Jan 24 22:22:21 +0000 2021',
#   'texto': 'RT @RebecaMorla: Pedro Freile tiene una claridad en su discurso envidiable para los otros candidatos. En todas sus respuestas va directo al…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['RebecaMorla'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'jacosta1984',
#   'followers': 28,
#   'friends': 533,
#   'create_count': 'Mon Jun 08 16:37:15 +0000 2009'},
#  {'fecha': 'Sun Jan 24 22:07:49 +0000 2021',
#   'texto': 'RT @ecuarauz: La corrupción ha sido el reparto de hospitales, los carnet falsificados, la trampa de los bancos, el prepago de la deuda mien…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1349,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'MaritzaPaezG1',
#   'followers': 52,
#   'friends': 254,
#   'create_count': 'Mon Jun 15 20:26:20 +0000 2020'},
#  {'fecha': 'Sun Jan 24 22:07:41 +0000 2021',
#   'texto': 'RT @ecuarauz: En 2015 me comprometí, por mi hijo, que lucharía para que el país no vuelva al pasado oprobioso. Cumplí y millones de ecuator…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1339,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'MaritzaPaezG1',
#   'followers': 52,
#   'friends': 254,
#   'create_count': 'Mon Jun 15 20:26:20 +0000 2020'},
#  {'fecha': 'Sun Jan 24 21:53:56 +0000 2021',
#   'texto': 'RT @ecu_encuestas: Después del #DebatePresidencial2021 y a 2 semanas de las #Elecciones2021 \n\n¿Por quién vas a votar el próximo 7 de Febrer…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'Elecciones2021'],
#   'num_hashtags': 2,
#   'mencions': ['ecu_encuestas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 119,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Cesar8111983',
#   'followers': 226,
#   'friends': 460,
#   'create_count': 'Sat Apr 07 22:05:49 +0000 2012'},
#  {'fecha': 'Sun Jan 24 21:38:27 +0000 2021',
#   'texto': 'RT @VickyDesintonio: 🔴 EN VIVO | Segunda jornada del #DebatePresidencial2021. Conoce las propuestas de Andrés Arauz, Lista 1-5, para #Recup…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['VickyDesintonio'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 19,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'krlo3rra',
#   'followers': 4,
#   'friends': 41,
#   'create_count': 'Thu Feb 20 18:28:50 +0000 2020'},
#  {'fecha': 'Sun Jan 24 21:12:32 +0000 2021',
#   'texto': 'RT @christianzr: En #DebatePresidencial2021 @ecuarauz debe responder sobre su participación en agresivo endeudamiento externo cuando ocupó…',
#   'longuitud': 139,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['christianzr', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 517,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'FaustoCoboM3',
#   'followers': 3267,
#   'friends': 211,
#   'create_count': 'Mon May 29 15:52:39 +0000 2017'},
#  {'fecha': 'Sun Jan 24 21:09:08 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Tannya_Garcia_R',
#   'followers': 53,
#   'friends': 270,
#   'create_count': 'Thu Jul 10 00:49:50 +0000 2014'},
#  {'fecha': 'Sun Jan 24 21:08:24 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'XavierRobles22',
#   'followers': 23,
#   'friends': 309,
#   'create_count': 'Thu Aug 14 14:11:46 +0000 2014'},
#  {'fecha': 'Sun Jan 24 21:01:14 +0000 2021',
#   'texto': 'RT @Robergansitos: Gran video #Ecuador haciéndonos  recordar un poco sobre los pensamientos de prófugo de Rafael Correa. Pensamientos que s…',
#   'longuitud': 140,
#   'hashtags': ['Ecuador'],
#   'num_hashtags': 1,
#   'mencions': ['Robergansitos'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'CesarGarrrca',
#   'followers': 73,
#   'friends': 171,
#   'create_count': 'Tue Sep 05 13:59:59 +0000 2017'},
#  {'fecha': 'Sun Jan 24 20:51:55 +0000 2021',
#   'texto': 'RT @ecuarauz: Me reuní en Argentina en calidad del futuro Presidente del Ecuador. Hemos iniciado las conversaciones para que la vacuna de O…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1315,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'daniel248297',
#   'followers': 262,
#   'friends': 600,
#   'create_count': 'Wed Jul 25 19:44:26 +0000 2012'},
#  {'fecha': 'Sun Jan 24 20:51:52 +0000 2021',
#   'texto': 'RT @ecuarauz: Vamos a volver a la integración regional, para recuperar fuerza de negociación. Por ejemplo, me reuní con el Presidente de Ar…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 877,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'daniel248297',
#   'followers': 262,
#   'friends': 600,
#   'create_count': 'Wed Jul 25 19:44:26 +0000 2012'},
#  {'fecha': 'Sun Jan 24 20:51:34 +0000 2021',
#   'texto': 'RT @JulianMaciasT: He analizado los más de 80.000 tuits lanzados con el HT #DebatePresidencial2021 que fue TT1 durante las dos jornadas del…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['JulianMaciasT'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 695,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'ZHAINOX',
#   'followers': 2593,
#   'friends': 2614,
#   'create_count': 'Mon Jul 06 15:24:43 +0000 2009'},
#  {'fecha': 'Sun Jan 24 20:51:20 +0000 2021',
#   'texto': 'RT @karlalopeztv: El Acuerdo comercial de primera fase entre #Ecuador y #EstadosUnidos contribuirá a reforzar la competitividad de nuestras…',
#   'longuitud': 140,
#   'hashtags': ['Ecuador', 'EstadosUnidos'],
#   'num_hashtags': 2,
#   'mencions': ['karlalopeztv'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AndreaBelen94',
#   'followers': 281,
#   'friends': 385,
#   'create_count': 'Tue Apr 15 20:46:45 +0000 2014'},
#  {'fecha': 'Sun Jan 24 20:42:37 +0000 2021',
#   'texto': 'RT @ecu_encuestas: Después del #DebatePresidencial2021 y a 2 semanas de las #Elecciones2021 \n\n¿Por quién vas a votar el próximo 7 de Febrer…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'Elecciones2021'],
#   'num_hashtags': 2,
#   'mencions': ['ecu_encuestas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 119,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'ScorpionVevo',
#   'followers': 736,
#   'friends': 1667,
#   'create_count': 'Mon Aug 31 17:54:21 +0000 2015'},
#  {'fecha': 'Sun Jan 24 20:12:37 +0000 2021',
#   'texto': 'Seguimos con las Fichas Técnicas sobre los candidatos a la presidencia, esta vez es el turno del candidato a la presidencia Yaku Perez\n#Elecciones2021Ec  #DebatePresidencial2021 \nPlan de gobierno completo cortesía de diario El Comercio:\nhttps://t.co/AMWCy3lvhx https://t.co/IdHnI1chd0',
#   'longuitud': 284,
#   'hashtags': ['Elecciones2021Ec', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'jonatan1100',
#   'followers': 11,
#   'friends': 142,
#   'create_count': 'Sat Nov 30 22:18:01 +0000 2013'},
#  {'fecha': 'Sun Jan 24 19:46:35 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'RLilliegren',
#   'followers': 179,
#   'friends': 514,
#   'create_count': 'Wed May 20 17:57:36 +0000 2020'},
#  {'fecha': 'Sun Jan 24 19:29:21 +0000 2021',
#   'texto': 'RT @dama_rosas: Viene bien ver ésto, justo ahora que están en campaña los candidatos.\n#DebatePresidencial2021 😁 #humor https://t.co/FsMleRY…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'humor'],
#   'num_hashtags': 2,
#   'mencions': ['dama_rosas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'pdiaz1977',
#   'followers': 165,
#   'friends': 706,
#   'create_count': 'Thu May 29 17:17:31 +0000 2014'},
#  {'fecha': 'Sun Jan 24 18:46:30 +0000 2021',
#   'texto': 'RT @ecuarauz: En 2015 me comprometí, por mi hijo, que lucharía para que el país no vuelva al pasado oprobioso. Cumplí y millones de ecuator…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1339,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'bayas_segundo',
#   'followers': 15,
#   'friends': 286,
#   'create_count': 'Wed Jul 19 15:18:58 +0000 2017'},
#  {'fecha': 'Sun Jan 24 18:46:25 +0000 2021',
#   'texto': 'RT @ecuarauz: Felices por finalizar el #DebatePresidencial2021. Expusimos nuestras propuestas sin peleas, ni odio. Motivados por nuestra ún…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1267,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'bayas_segundo',
#   'followers': 15,
#   'friends': 286,
#   'create_count': 'Wed Jul 19 15:18:58 +0000 2017'},
#  {'fecha': 'Sun Jan 24 18:46:16 +0000 2021',
#   'texto': 'RT @ecuarauz: Vamos a volver a la integración regional, para recuperar fuerza de negociación. Por ejemplo, me reuní con el Presidente de Ar…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 877,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'bayas_segundo',
#   'followers': 15,
#   'friends': 286,
#   'create_count': 'Wed Jul 19 15:18:58 +0000 2017'},
#  {'fecha': 'Sun Jan 24 18:46:15 +0000 2021',
#   'texto': 'RT @ecuarauz: La corrupción ha sido el reparto de hospitales, los carnet falsificados, la trampa de los bancos, el prepago de la deuda mien…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1349,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'bayas_segundo',
#   'followers': 15,
#   'friends': 286,
#   'create_count': 'Wed Jul 19 15:18:58 +0000 2017'},
#  {'fecha': 'Sun Jan 24 18:34:35 +0000 2021',
#   'texto': '#ProhibidoOlvidar #DebatePresidencial2021 #leloesvenezuela cuando se se visten de ovejas. Vale la pena escucharlo. https://t.co/DBDXKBiY3b',
#   'longuitud': 138,
#   'hashtags': ['ProhibidoOlvidar',
#    'DebatePresidencial2021',
#    'leloesvenezuela'],
#   'num_hashtags': 3,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'CJV1981',
#   'followers': 121,
#   'friends': 653,
#   'create_count': 'Sat Nov 30 15:04:40 +0000 2019'},
#  {'fecha': 'Sun Jan 24 17:58:17 +0000 2021',
#   'texto': 'RT @EcUnidad: Los guayaquileños respaldan a @ecuarauz. En el  segundo día previo al #DebatePresidencial2021. Así es la expresión de cariño…',
#   'longuitud': 139,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['EcUnidad', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'XaviSanCor',
#   'followers': 286,
#   'friends': 59,
#   'create_count': 'Wed Jun 28 15:39:19 +0000 2017'},
#  {'fecha': 'Sun Jan 24 17:37:03 +0000 2021',
#   'texto': 'RT @pacohidalgof: 📺@ecuarauz \n#DebatePresidencial2021 \n"Mi trabajo será generar trabajo para ustedes"\n\nYa tenemos Presidente, #MiPresidente…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['pacohidalgof', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 54,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Fernand93510660',
#   'followers': 30,
#   'friends': 45,
#   'create_count': 'Fri May 29 18:35:44 +0000 2020'},
#  {'fecha': 'Sun Jan 24 17:19:33 +0000 2021',
#   'texto': 'RT @dama_rosas: Viene bien ver ésto, justo ahora que están en campaña los candidatos.\n#DebatePresidencial2021 😁 #humor https://t.co/FsMleRY…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'humor'],
#   'num_hashtags': 2,
#   'mencions': ['dama_rosas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'wilfrido_jativa',
#   'followers': 83,
#   'friends': 501,
#   'create_count': 'Sat Oct 17 17:56:13 +0000 2020'},
#  {'fecha': 'Sun Jan 24 17:15:20 +0000 2021',
#   'texto': 'RT @ecuarauz: Demostramos que nuestras propuestas son más fuertes que los ataques y la campaña sucia. Gracias familias ecuatorianas por el…',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1813,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'fhers1_fernando',
#   'followers': 11,
#   'friends': 58,
#   'create_count': 'Sun Apr 21 05:19:31 +0000 2013'},
#  {'fecha': 'Sun Jan 24 16:39:35 +0000 2021',
#   'texto': 'RT @ajungbluth: Gracias a todos por sus comentarios  del #DebatePresidencial2021 del @cnegobec. Un honor volver a compartir con @RuthdelSal…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['ajungbluth', 'cnegobec'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 23,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'NoSarago',
#   'followers': 16,
#   'friends': 13,
#   'create_count': 'Sun Nov 05 15:48:07 +0000 2017'},
#  {'fecha': 'Sun Jan 24 16:34:24 +0000 2021',
#   'texto': 'RT @RebecaMorla: Pedro Freile tiene una claridad en su discurso envidiable para los otros candidatos. En todas sus respuestas va directo al…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['RebecaMorla'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': '_ClauGiler',
#   'followers': 583,
#   'friends': 230,
#   'create_count': 'Sat May 05 02:10:52 +0000 2012'},
#  {'fecha': 'Sun Jan 24 16:33:28 +0000 2021',
#   'texto': 'RT @paar8803: @MashiRafael Fue tan convincente en el debate, que desde Latacunga están con la 1 #DebatePresidencial2021 #Elecciones2021 #Ar…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'Elecciones2021'],
#   'num_hashtags': 2,
#   'mencions': ['paar8803', 'MashiRafael'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 10,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'victors99273341',
#   'followers': 20,
#   'friends': 60,
#   'create_count': 'Thu Jun 04 17:58:27 +0000 2020'},
#  {'fecha': 'Sun Jan 24 16:31:37 +0000 2021',
#   'texto': 'RT @mabsegovia: #DebatePresidencial2021 \n\nLa presencia de @ecuarauz en el evento del CNE fue casi un milagro  después de que los poderes fá…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['mabsegovia', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 360,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Niki41625433',
#   'followers': 30,
#   'friends': 509,
#   'create_count': 'Sat Jan 16 08:28:07 +0000 2021'},
#  {'fecha': 'Sun Jan 24 16:30:59 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AntonioGarciaEC',
#   'followers': 10468,
#   'friends': 388,
#   'create_count': 'Wed May 11 05:44:15 +0000 2011'},
#  {'fecha': 'Sun Jan 24 16:23:40 +0000 2021',
#   'texto': 'RT @CompromisoRC: #AndrésCapacidadYFuturo | La vida, el desempeño profesional y académico de Andrés Arauz (@ecuarauz) es limpio. Evidencia…',
#   'longuitud': 139,
#   'hashtags': ['AndrésCapacidadYFuturo'],
#   'num_hashtags': 1,
#   'mencions': ['CompromisoRC', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 89,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'ANTONIO18486030',
#   'followers': 1,
#   'friends': 19,
#   'create_count': 'Thu Jan 07 16:46:14 +0000 2021'},
#  {'fecha': 'Sun Jan 24 16:16:05 +0000 2021',
#   'texto': 'RT @dama_rosas: Viene bien ver ésto, justo ahora que están en campaña los candidatos.\n#DebatePresidencial2021 😁 #humor https://t.co/FsMleRY…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'humor'],
#   'num_hashtags': 2,
#   'mencions': ['dama_rosas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'perroconhueso',
#   'followers': 362,
#   'friends': 385,
#   'create_count': 'Sun Apr 17 11:55:41 +0000 2016'},
#  {'fecha': 'Sun Jan 24 16:00:42 +0000 2021',
#   'texto': 'RT @dama_rosas: Viene bien ver ésto, justo ahora que están en campaña los candidatos.\n#DebatePresidencial2021 😁 #humor https://t.co/FsMleRY…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021', 'humor'],
#   'num_hashtags': 2,
#   'mencions': ['dama_rosas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'walvarracin',
#   'followers': 95,
#   'friends': 790,
#   'create_count': 'Tue Mar 22 16:19:07 +0000 2011'},
#  {'fecha': 'Sun Jan 24 15:59:21 +0000 2021',
#   'texto': 'RT @EcuatorianoUni2: Pongámosle el pie en la garganta a la corrupción, cortémosle la cabeza, sembremos la semilla de la prosperidad, constr…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['EcuatorianoUni2'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 25,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'JuanRiSantos',
#   'followers': 161,
#   'friends': 468,
#   'create_count': 'Sun Jan 23 05:05:15 +0000 2011'},
#  {'fecha': 'Sun Jan 24 15:55:48 +0000 2021',
#   'texto': 'Viene bien ver ésto, justo ahora que están en campaña los candidatos.\n#DebatePresidencial2021 😁 #humor https://t.co/FsMleRYpj1',
#   'longuitud': 126,
#   'hashtags': ['DebatePresidencial2021', 'humor'],
#   'num_hashtags': 2,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 5,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'dama_rosas',
#   'followers': 7706,
#   'friends': 1607,
#   'create_count': 'Tue Jan 22 21:00:25 +0000 2013'},
#  {'fecha': 'Sun Jan 24 15:54:24 +0000 2021',
#   'texto': 'RT @eldatoec: Haz tu cuestionario en https://t.co/ifvcngOBjN para no valer votando, infórmate más sobre los candidatos a la presidencia de…',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['eldatoec'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'twiteandofer',
#   'followers': 397,
#   'friends': 479,
#   'create_count': 'Sat Sep 15 08:39:55 +0000 2012'},
#  {'fecha': 'Sun Jan 24 15:48:55 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'LarreaDiana',
#   'followers': 55,
#   'friends': 88,
#   'create_count': 'Fri Oct 02 01:52:25 +0000 2015'},
#  {'fecha': 'Sun Jan 24 15:45:08 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'aperaltamarin',
#   'followers': 666,
#   'friends': 199,
#   'create_count': 'Mon Jun 24 20:48:21 +0000 2019'},
#  {'fecha': 'Sun Jan 24 15:29:57 +0000 2021',
#   'texto': 'RT @GustavoLarreaSi: Esta noche estaré en el #DebatePresidencial2021 de @tctelevision para exponer mis propuestas de Gobierno sobre crédito…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['GustavoLarreaSi', 'tctelevision'],
#   'num_mencions': 2,
# ...
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['Karroceinforma'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Karroceinforma',
#   'followers': 48,
#   'friends': 182,
#   'create_count': 'Thu Jul 02 11:49:20 +0000 2020'},
#  {'fecha': 'Thu Jan 21 02:06:32 +0000 2021',
#   'texto': '¿Qué empresas subieron sus pagos de rodamientos para el servicio público? ¿Por qué motivo lo hacen en medio de una crisis económica?\n#apoyaelservicioespecial \n#bogotá #DebatePresidencial2021 #Elecciones2021 #transporte #ministeriodetransporte #SuperTransporte #colombia',
#   'longuitud': 269,
#   'hashtags': ['apoyaelservicioespecial',
#    'bogotá',
#    'DebatePresidencial2021',
#    'Elecciones2021',
#    'transporte',
#    'ministeriodetransporte',
#    'SuperTransporte',
#    'colombia'],
#   'num_hashtags': 8,
#   'mencions': [],
#   'num_mencions': 0,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 4,
#   'name_place': 'Bogotá, D.C.',
#   'full_name_place': 'Bogotá, D.C., Colombia',
#   'country': 'Colombia',
#   'username': 'Karroceinforma',
#   'followers': 48,
#   'friends': 182,
#   'create_count': 'Thu Jul 02 11:49:20 +0000 2020'},
#  {'fecha': 'Thu Jan 21 02:06:11 +0000 2021',
#   'texto': 'RT @mashinancyg: Si te perdiste el #DebatePresidencial2021 o si te quedó alguna duda, aquí las respuestas👇🏽de nuestro compañero @ecuarauz #…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['mashinancyg', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 146,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Manuel76156233',
#   'followers': 1,
#   'friends': 7,
#   'create_count': 'Tue Oct 20 02:13:13 +0000 2020'},
#  {'fecha': 'Thu Jan 21 02:00:55 +0000 2021',
#   'texto': 'RT @EnMediatica: 😳16 candidatos participaron en el #DebatePresidencial2021 pero se volvieron excesivamente ridículos en las propuestas plan…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['EnMediatica'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'corellaleo3',
#   'followers': 807,
#   'friends': 585,
#   'create_count': 'Tue Feb 21 02:01:26 +0000 2017'},
#  {'fecha': 'Thu Jan 21 02:00:23 +0000 2021',
#   'texto': 'RT @xhervas: #DebatePresidencial2021 \n#EcuadorDecide2021\n#XavierHervasPresidente https://t.co/XI8dMxQM3g',
#   'longuitud': 104,
#   'hashtags': ['DebatePresidencial2021',
#    'EcuadorDecide2021',
#    'XavierHervasPresidente'],
#   'num_hashtags': 3,
#   'mencions': ['xhervas'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 282,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'amee09045163',
#   'followers': 0,
#   'friends': 21,
#   'create_count': 'Mon Jun 01 06:48:54 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:59:35 +0000 2021',
#   'texto': 'RT @ecuarauz: En 2015 me comprometí, por mi hijo, que lucharía para que el país no vuelva al pasado oprobioso. Cumplí y millones de ecuator…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1339,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'PapEsPap1',
#   'followers': 71,
#   'friends': 303,
#   'create_count': 'Thu Jan 31 01:24:34 +0000 2019'},
#  {'fecha': 'Thu Jan 21 01:57:50 +0000 2021',
#   'texto': 'RT @selenelo1711: 18 días antes de las elecciones ¿Cómo está la cosa? A raíz del #DebatePresidencial2021 y de revisar las campañas de los d…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['selenelo1711'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 22,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'corellaleo3',
#   'followers': 807,
#   'friends': 585,
#   'create_count': 'Tue Feb 21 02:01:26 +0000 2017'},
#  {'fecha': 'Thu Jan 21 01:56:44 +0000 2021',
#   'texto': 'RT @luisbenaventegi: "El problema es que el gobierno ha decidido ocultar la verdad". Comparto la entrevista que tuve con UCI Noticias. http…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['luisbenaventegi'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Jazzyplus',
#   'followers': 2137,
#   'friends': 904,
#   'create_count': 'Wed Aug 19 04:47:08 +0000 2015'},
#  {'fecha': 'Thu Jan 21 01:55:09 +0000 2021',
#   'texto': 'RT @xhervas: #DebatePresidencial2021 \n#EcuadorDecide2021\n#XavierHervasPresidente https://t.co/XI8dMxQM3g',
#   'longuitud': 104,
#   'hashtags': ['DebatePresidencial2021',
#    'EcuadorDecide2021',
#    'XavierHervasPresidente'],
#   'num_hashtags': 3,
#   'mencions': ['xhervas'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 282,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'MtinSubia',
#   'followers': 4,
#   'friends': 21,
#   'create_count': 'Thu Aug 24 21:01:27 +0000 2017'},
#  {'fecha': 'Thu Jan 21 01:50:15 +0000 2021',
#   'texto': 'RT @PrimatesUIO: Ya decía yo que lo vi en algún lado\n#DebatePresidencial2021 https://t.co/RqaC4aNPDX',
#   'longuitud': 100,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['PrimatesUIO'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'francisborj',
#   'followers': 277,
#   'friends': 1911,
#   'create_count': 'Mon Nov 22 15:58:56 +0000 2010'},
#  {'fecha': 'Thu Jan 21 01:47:23 +0000 2021',
#   'texto': 'RT @JuventudesRCE: Andrés Arauz @ecuarauz haciéndose un selfie con los demás candidatos después del #DebatePresidencial2021 https://t.co/zL…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['JuventudesRCE', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'forajida57',
#   'followers': 3885,
#   'friends': 509,
#   'create_count': 'Sun Apr 10 20:24:05 +0000 2011'},
#  {'fecha': 'Thu Jan 21 01:46:56 +0000 2021',
#   'texto': 'RT @mashinancyg: Si te perdiste el #DebatePresidencial2021 o si te quedó alguna duda, aquí las respuestas👇🏽de nuestro compañero @ecuarauz #…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['mashinancyg', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 146,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'genovevatorres2',
#   'followers': 13,
#   'friends': 33,
#   'create_count': 'Fri Feb 10 00:31:37 +0000 2012'},
#  {'fecha': 'Thu Jan 21 01:45:57 +0000 2021',
#   'texto': 'RT @JuventudesRCE: Andrés Arauz @ecuarauz haciéndose un selfie con los demás candidatos después del #DebatePresidencial2021 https://t.co/zL…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['JuventudesRCE', 'ecuarauz'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'ecua_accionbcn',
#   'followers': 204,
#   'friends': 291,
#   'create_count': 'Sun Feb 23 01:02:29 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:42:38 +0000 2021',
#   'texto': 'RT @ecuarauz: Demostramos que nuestras propuestas son más fuertes que los ataques y la campaña sucia. Gracias familias ecuatorianas por el…',
#   'longuitud': 139,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1813,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Madamelorraine1',
#   'followers': 16,
#   'friends': 115,
#   'create_count': 'Sat Sep 26 17:58:02 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:39:39 +0000 2021',
#   'texto': 'RT @xhervas: #DebatePresidencial2021 \n#EcuadorDecide2021\n#XavierHervasPresidente https://t.co/XI8dMxQM3g',
#   'longuitud': 104,
#   'hashtags': ['DebatePresidencial2021',
#    'EcuadorDecide2021',
#    'XavierHervasPresidente'],
#   'num_hashtags': 3,
#   'mencions': ['xhervas'],
#   'num_mencions': 1,
#   'language': 'und',
#   'retweet_count': 282,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'FootballDrock',
#   'followers': 1441,
#   'friends': 2679,
#   'create_count': 'Sat Aug 18 08:17:33 +0000 2012'},
#  {'fecha': 'Thu Jan 21 01:36:15 +0000 2021',
#   'texto': 'RT @sandracorrealeo: #EducarEducandonos\n\nPara el Comité y Moderador@s del #DebatePresidencial2021.\n\nLa ideología se muestra en las pregunta…',
#   'longuitud': 140,
#   'hashtags': ['EducarEducandonos', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['sandracorrealeo'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'OTOBAR51',
#   'followers': 93,
#   'friends': 583,
#   'create_count': 'Fri Dec 22 23:27:03 +0000 2017'},
#  {'fecha': 'Thu Jan 21 01:30:55 +0000 2021',
#   'texto': 'RT @PlacnciaGuilkpi: Ya va a empezar la serenata de @juanfervelasco a la esposa de #Andrade?\n🎂\n\n#DebatePresidencial2021 #DebatePresidencial…',
#   'longuitud': 140,
#   'hashtags': ['Andrade', 'DebatePresidencial2021', 'DebatePresidencial'],
#   'num_hashtags': 3,
#   'mencions': ['PlacnciaGuilkpi', 'juanfervelasco'],
#   'num_mencions': 2,
#   'language': 'es',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'AileenBurgos4',
#   'followers': 3,
#   'friends': 13,
#   'create_count': 'Wed Nov 18 03:38:39 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:28:56 +0000 2021',
#   'texto': 'RT @selenelo1711: 18 días antes de las elecciones ¿Cómo está la cosa? A raíz del #DebatePresidencial2021 y de revisar las campañas de los d…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['selenelo1711'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 22,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'josephcuevag',
#   'followers': 7171,
#   'friends': 3796,
#   'create_count': 'Mon Dec 08 16:17:05 +0000 2008'},
#  {'fecha': 'Thu Jan 21 01:27:51 +0000 2021',
#   'texto': 'RT @ecuarauz: En 2015 me comprometí, por mi hijo, que lucharía para que el país no vuelva al pasado oprobioso. Cumplí y millones de ecuator…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1339,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'LuisMerizalde13',
#   'followers': 17,
#   'friends': 94,
#   'create_count': 'Thu Nov 19 02:00:51 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:26:40 +0000 2021',
#   'texto': 'RT @KinttoLucas: Si sabrán que el pueblo quiere a Andrés Arauz, que los otros candidatos, en lugar de hacer propuestas solo lo atacan con m…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['KinttoLucas'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 127,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'RomPatrick2',
#   'followers': 85,
#   'friends': 143,
#   'create_count': 'Mon Mar 30 21:56:53 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:26:38 +0000 2021',
#   'texto': 'RT @PaolaCabezasC: 🔴#EnVivo ll Hoy en @EnClavePolitik el periodista @OrlandoPerezEC habla sobre la evaluación del #DebatePresidencial2021 e…',
#   'longuitud': 140,
#   'hashtags': ['EnVivo', 'DebatePresidencial2021'],
#   'num_hashtags': 2,
#   'mencions': ['PaolaCabezasC', 'EnClavePolitik', 'OrlandoPerezEC'],
#   'num_mencions': 3,
#   'language': 'es',
#   'retweet_count': 12,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'Herederos_RC',
#   'followers': 2404,
#   'friends': 1089,
#   'create_count': 'Thu Oct 29 18:16:06 +0000 2015'},
#  {'fecha': 'Thu Jan 21 01:22:51 +0000 2021',
#   'texto': 'RT @ecuarauz: Felices por finalizar el #DebatePresidencial2021. Expusimos nuestras propuestas sin peleas, ni odio. Motivados por nuestra ún…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1267,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'fercho2072',
#   'followers': 158,
#   'friends': 372,
#   'create_count': 'Wed Aug 11 01:43:05 +0000 2010'},
#  {'fecha': 'Thu Jan 21 01:22:29 +0000 2021',
#   'texto': 'RT @ecuarauz: Felices por finalizar el #DebatePresidencial2021. Expusimos nuestras propuestas sin peleas, ni odio. Motivados por nuestra ún…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['ecuarauz'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 1267,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'LuisMerizalde13',
#   'followers': 17,
#   'friends': 94,
#   'create_count': 'Thu Nov 19 02:00:51 +0000 2020'},
#  {'fecha': 'Thu Jan 21 01:15:56 +0000 2021',
#   'texto': 'RT @MariaBelenArro1: Un periodista puede contrarrestar con datos una información falaz que presente el candidato en #DebatePresidencial2021…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['MariaBelenArro1'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'harryaureo1',
#   'followers': 315,
#   'friends': 536,
#   'create_count': 'Sun Mar 04 04:40:06 +0000 2018'},
#  {'fecha': 'Thu Jan 21 01:15:50 +0000 2021',
#   'texto': 'RT @MariaBelenArro1: El populismo entendió que cada vez somos menos racionales y más emocionales, y aprovecha eso para captar votos. El #De…',
#   'longuitud': 140,
#   'hashtags': [],
#   'num_hashtags': 0,
#   'mencions': ['MariaBelenArro1'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'harryaureo1',
#   'followers': 315,
#   'friends': 536,
#   'create_count': 'Sun Mar 04 04:40:06 +0000 2018'},
#  {'fecha': 'Thu Jan 21 01:15:46 +0000 2021',
#   'texto': 'RT @MariaBelenArro1: "No cabe dramatizar las dificultades del #DebatePresidencial2021 ni minimizar los problemas, porque pueden persistir e…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['MariaBelenArro1'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'harryaureo1',
#   'followers': 315,
#   'friends': 536,
#   'create_count': 'Sun Mar 04 04:40:06 +0000 2018'},
#  {'fecha': 'Thu Jan 21 01:15:40 +0000 2021',
#   'texto': 'RT @MariaBelenArro1: Un asistente al foro comparte la desazón y desilusión frente al #DebatePresidencial2021 al ver la inconsistencia de la…',
#   'longuitud': 140,
#   'hashtags': ['DebatePresidencial2021'],
#   'num_hashtags': 1,
#   'mencions': ['MariaBelenArro1'],
#   'num_mencions': 1,
#   'language': 'es',
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'name_place': nan,
#   'full_name_place': nan,
#   'country': nan,
#   'username': 'harryaureo1',
#   'followers': 315,
#   'friends': 536,
#   'create_count': 'Sun Mar 04 04:40:06 +0000 2018'},
#  ...]

# %%
len(tweets_apis)
# Out:
# 68771

# %%
df = get_DataFrame(tweets_apis)
df
# Out:
#                                                                        texto  \
# fecha
# 2021-01-24 22:55:37+00:00  RT @cicloviagye: 1 bicicleta &gt; economía ecu...
# 2021-01-24 21:57:22+00:00  RT @ecuarauz: En 2015 me comprometí, por mi hi...
# 2021-01-24 21:46:55+00:00  RT @64W48: Lasso una vez mas hablando del pasa...
# 2021-01-24 21:27:04+00:00  RT @DamianR1991: Interesante análisis del #Deb...
# 2021-01-24 20:47:29+00:00  RT @yakuperezg: Además en la Consulta Popular ...
# ...                                                                      ...
# 2021-01-17 06:24:18+00:00  A todos los candidatos para Presidente los met...
# 2021-01-17 06:23:53+00:00  RT @inclusionpueblo: Lasso | ¿Cuánto cobra el ...
# 2021-01-17 06:23:20+00:00  RT @mateoizquierd0: Que sentirá cualquiera de ...
# 2021-01-17 06:23:08+00:00  RT @ecuarauz: #DebatePresidencial2021\n\nVamos...
# 2021-01-17 06:22:40+00:00  RT @CompromisoRC: #AndrésGanaDe1 | “Mi trabajo...
#
#                            longuitud  \
# fecha
# 2021-01-24 22:55:37+00:00         80
# 2021-01-24 21:57:22+00:00        140
# 2021-01-24 21:46:55+00:00        140
# 2021-01-24 21:27:04+00:00         93
# 2021-01-24 20:47:29+00:00        140
# ...                              ...
# 2021-01-17 06:24:18+00:00        105
# 2021-01-17 06:23:53+00:00        140
# 2021-01-17 06:23:20+00:00        140
# 2021-01-17 06:23:08+00:00        140
# 2021-01-17 06:22:40+00:00        140
#
#                                                            hashtags  \
# fecha
# 2021-01-24 22:55:37+00:00                  [DebatePresidencial2021]
# 2021-01-24 21:57:22+00:00                                        []
# 2021-01-24 21:46:55+00:00                                        []
# 2021-01-24 21:27:04+00:00  [DebatePresidencial2021, socialnetworks]
# 2021-01-24 20:47:29+00:00                                        []
# ...                                                             ...
# 2021-01-17 06:24:18+00:00                  [DebatePresidencial2021]
# 2021-01-17 06:23:53+00:00                               [SabíasQue]
# 2021-01-17 06:23:20+00:00                                        []
# 2021-01-17 06:23:08+00:00                  [DebatePresidencial2021]
# 2021-01-17 06:22:40+00:00   [AndrésGanaDe1, DebatePresidencial2021]
#
#                            num_hashtags  \
# fecha
# 2021-01-24 22:55:37+00:00             1
# 2021-01-24 21:57:22+00:00             0
# 2021-01-24 21:46:55+00:00             0
# 2021-01-24 21:27:04+00:00             2
# 2021-01-24 20:47:29+00:00             0
# ...                                 ...
# 2021-01-17 06:24:18+00:00             1
# 2021-01-17 06:23:53+00:00             1
# 2021-01-17 06:23:20+00:00             0
# 2021-01-17 06:23:08+00:00             1
# 2021-01-17 06:22:40+00:00             2
#
#                                                         mencions  \
# fecha
# 2021-01-24 22:55:37+00:00                          [cicloviagye]
# 2021-01-24 21:57:22+00:00                             [ecuarauz]
# 2021-01-24 21:46:55+00:00                                [64W48]
# 2021-01-24 21:27:04+00:00                          [DamianR1991]
# 2021-01-24 20:47:29+00:00                           [yakuperezg]
# ...                                                          ...
# 2021-01-17 06:24:18+00:00                                     []
# 2021-01-17 06:23:53+00:00      [inclusionpueblo, BancoGuayaquil]
# 2021-01-17 06:23:20+00:00                       [mateoizquierd0]
# 2021-01-17 06:23:08+00:00                             [ecuarauz]
# 2021-01-17 06:22:40+00:00  [CompromisoRC, ecuarauz, MashiRafael]
#
#                            num_mencions language  retweet_count  \
# fecha
# 2021-01-24 22:55:37+00:00             1       es              1
# 2021-01-24 21:57:22+00:00             1       es           1339
# 2021-01-24 21:46:55+00:00             1       es              7
# 2021-01-24 21:27:04+00:00             1       es              3
# 2021-01-24 20:47:29+00:00             1       es             34
# ...                                 ...      ...            ...
# 2021-01-17 06:24:18+00:00             0       es              0
# 2021-01-17 06:23:53+00:00             2       es             97
# 2021-01-17 06:23:20+00:00             1       es             64
# 2021-01-17 06:23:08+00:00             1       es            955
# 2021-01-17 06:22:40+00:00             3       es            359
#
#                            favorite_count name_place full_name_place country  \
# fecha
# 2021-01-24 22:55:37+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:57:22+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:46:55+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:27:04+00:00               0        NaN             NaN     NaN
# 2021-01-24 20:47:29+00:00               0        NaN             NaN     NaN
# ...                                   ...        ...             ...     ...
# 2021-01-17 06:24:18+00:00               2        NaN             NaN     NaN
# 2021-01-17 06:23:53+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:23:20+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:23:08+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:22:40+00:00               0        NaN             NaN     NaN
#
#                                   username  followers  friends  \
# fecha
# 2021-01-24 22:55:37+00:00      caritoloitu          7       65
# 2021-01-24 21:57:22+00:00  royrichard20051        378      287
# 2021-01-24 21:46:55+00:00          NiBurro          0       14
# 2021-01-24 21:27:04+00:00     TejadaRommel        120      496
# 2021-01-24 20:47:29+00:00        kamizvlog       1065     2322
# ...                                    ...        ...      ...
# 2021-01-17 06:24:18+00:00       mariserr79       1101     2792
# 2021-01-17 06:23:53+00:00   DELATORREMERCE        319      339
# 2021-01-17 06:23:20+00:00    OcampoMarieta        588      100
# 2021-01-17 06:23:08+00:00     PiCuboLogico         97       14
# 2021-01-17 06:22:40+00:00   DELATORREMERCE        319      339
#
#                                        create_count
# fecha
# 2021-01-24 22:55:37+00:00 2020-12-31 17:41:58+00:00
# 2021-01-24 21:57:22+00:00 2012-11-21 15:52:08+00:00
# 2021-01-24 21:46:55+00:00 2021-01-05 16:22:12+00:00
# 2021-01-24 21:27:04+00:00 2014-03-13 01:35:17+00:00
# 2021-01-24 20:47:29+00:00 2011-11-13 20:33:37+00:00
# ...                                             ...
# 2021-01-17 06:24:18+00:00 2011-08-24 18:39:34+00:00
# 2021-01-17 06:23:53+00:00 2013-04-08 00:14:27+00:00
# 2021-01-17 06:23:20+00:00 2019-10-20 18:43:54+00:00
# 2021-01-17 06:23:08+00:00 2012-12-15 22:18:48+00:00
# 2021-01-17 06:22:40+00:00 2013-04-08 00:14:27+00:00
#
# [68771 rows x 16 columns]

# %%
df.to_pickle('tw.pkl')

# %%
df
# Out:
#                                                                        texto  \
# fecha
# 2021-01-24 22:55:37+00:00  RT @cicloviagye: 1 bicicleta &gt; economía ecu...
# 2021-01-24 21:57:22+00:00  RT @ecuarauz: En 2015 me comprometí, por mi hi...
# 2021-01-24 21:46:55+00:00  RT @64W48: Lasso una vez mas hablando del pasa...
# 2021-01-24 21:27:04+00:00  RT @DamianR1991: Interesante análisis del #Deb...
# 2021-01-24 20:47:29+00:00  RT @yakuperezg: Además en la Consulta Popular ...
# ...                                                                      ...
# 2021-01-17 06:24:18+00:00  A todos los candidatos para Presidente los met...
# 2021-01-17 06:23:53+00:00  RT @inclusionpueblo: Lasso | ¿Cuánto cobra el ...
# 2021-01-17 06:23:20+00:00  RT @mateoizquierd0: Que sentirá cualquiera de ...
# 2021-01-17 06:23:08+00:00  RT @ecuarauz: #DebatePresidencial2021\n\nVamos...
# 2021-01-17 06:22:40+00:00  RT @CompromisoRC: #AndrésGanaDe1 | “Mi trabajo...
#
#                            longuitud  \
# fecha
# 2021-01-24 22:55:37+00:00         80
# 2021-01-24 21:57:22+00:00        140
# 2021-01-24 21:46:55+00:00        140
# 2021-01-24 21:27:04+00:00         93
# 2021-01-24 20:47:29+00:00        140
# ...                              ...
# 2021-01-17 06:24:18+00:00        105
# 2021-01-17 06:23:53+00:00        140
# 2021-01-17 06:23:20+00:00        140
# 2021-01-17 06:23:08+00:00        140
# 2021-01-17 06:22:40+00:00        140
#
#                                                            hashtags  \
# fecha
# 2021-01-24 22:55:37+00:00                  [DebatePresidencial2021]
# 2021-01-24 21:57:22+00:00                                        []
# 2021-01-24 21:46:55+00:00                                        []
# 2021-01-24 21:27:04+00:00  [DebatePresidencial2021, socialnetworks]
# 2021-01-24 20:47:29+00:00                                        []
# ...                                                             ...
# 2021-01-17 06:24:18+00:00                  [DebatePresidencial2021]
# 2021-01-17 06:23:53+00:00                               [SabíasQue]
# 2021-01-17 06:23:20+00:00                                        []
# 2021-01-17 06:23:08+00:00                  [DebatePresidencial2021]
# 2021-01-17 06:22:40+00:00   [AndrésGanaDe1, DebatePresidencial2021]
#
#                            num_hashtags  \
# fecha
# 2021-01-24 22:55:37+00:00             1
# 2021-01-24 21:57:22+00:00             0
# 2021-01-24 21:46:55+00:00             0
# 2021-01-24 21:27:04+00:00             2
# 2021-01-24 20:47:29+00:00             0
# ...                                 ...
# 2021-01-17 06:24:18+00:00             1
# 2021-01-17 06:23:53+00:00             1
# 2021-01-17 06:23:20+00:00             0
# 2021-01-17 06:23:08+00:00             1
# 2021-01-17 06:22:40+00:00             2
#
#                                                         mencions  \
# fecha
# 2021-01-24 22:55:37+00:00                          [cicloviagye]
# 2021-01-24 21:57:22+00:00                             [ecuarauz]
# 2021-01-24 21:46:55+00:00                                [64W48]
# 2021-01-24 21:27:04+00:00                          [DamianR1991]
# 2021-01-24 20:47:29+00:00                           [yakuperezg]
# ...                                                          ...
# 2021-01-17 06:24:18+00:00                                     []
# 2021-01-17 06:23:53+00:00      [inclusionpueblo, BancoGuayaquil]
# 2021-01-17 06:23:20+00:00                       [mateoizquierd0]
# 2021-01-17 06:23:08+00:00                             [ecuarauz]
# 2021-01-17 06:22:40+00:00  [CompromisoRC, ecuarauz, MashiRafael]
#
#                            num_mencions language  retweet_count  \
# fecha
# 2021-01-24 22:55:37+00:00             1       es              1
# 2021-01-24 21:57:22+00:00             1       es           1339
# 2021-01-24 21:46:55+00:00             1       es              7
# 2021-01-24 21:27:04+00:00             1       es              3
# 2021-01-24 20:47:29+00:00             1       es             34
# ...                                 ...      ...            ...
# 2021-01-17 06:24:18+00:00             0       es              0
# 2021-01-17 06:23:53+00:00             2       es             97
# 2021-01-17 06:23:20+00:00             1       es             64
# 2021-01-17 06:23:08+00:00             1       es            955
# 2021-01-17 06:22:40+00:00             3       es            359
#
#                            favorite_count name_place full_name_place country  \
# fecha
# 2021-01-24 22:55:37+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:57:22+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:46:55+00:00               0        NaN             NaN     NaN
# 2021-01-24 21:27:04+00:00               0        NaN             NaN     NaN
# 2021-01-24 20:47:29+00:00               0        NaN             NaN     NaN
# ...                                   ...        ...             ...     ...
# 2021-01-17 06:24:18+00:00               2        NaN             NaN     NaN
# 2021-01-17 06:23:53+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:23:20+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:23:08+00:00               0        NaN             NaN     NaN
# 2021-01-17 06:22:40+00:00               0        NaN             NaN     NaN
#
#                                   username  followers  friends  \
# fecha
# 2021-01-24 22:55:37+00:00      caritoloitu          7       65
# 2021-01-24 21:57:22+00:00  royrichard20051        378      287
# 2021-01-24 21:46:55+00:00          NiBurro          0       14
# 2021-01-24 21:27:04+00:00     TejadaRommel        120      496
# 2021-01-24 20:47:29+00:00        kamizvlog       1065     2322
# ...                                    ...        ...      ...
# 2021-01-17 06:24:18+00:00       mariserr79       1101     2792
# 2021-01-17 06:23:53+00:00   DELATORREMERCE        319      339
# 2021-01-17 06:23:20+00:00    OcampoMarieta        588      100
# 2021-01-17 06:23:08+00:00     PiCuboLogico         97       14
# 2021-01-17 06:22:40+00:00   DELATORREMERCE        319      339
#
#                                        create_count
# fecha
# 2021-01-24 22:55:37+00:00 2020-12-31 17:41:58+00:00
# 2021-01-24 21:57:22+00:00 2012-11-21 15:52:08+00:00
# 2021-01-24 21:46:55+00:00 2021-01-05 16:22:12+00:00
# 2021-01-24 21:27:04+00:00 2014-03-13 01:35:17+00:00
# 2021-01-24 20:47:29+00:00 2011-11-13 20:33:37+00:00
# ...                                             ...
# 2021-01-17 06:24:18+00:00 2011-08-24 18:39:34+00:00
# 2021-01-17 06:23:53+00:00 2013-04-08 00:14:27+00:00
# 2021-01-17 06:23:20+00:00 2019-10-20 18:43:54+00:00
# 2021-01-17 06:23:08+00:00 2012-12-15 22:18:48+00:00
# 2021-01-17 06:22:40+00:00 2013-04-08 00:14:27+00:00
#
# [68771 rows x 16 columns]

# %%
df1 = pd.read_csv('data/tweets.csv')
from ast import literal_eval

df1['fecha'] = pd.to_datetime(df1['fecha'])
df1['create_count'] = pd.to_datetime(df1['create_count'])
# df1['hashtags'] = df1['hashtags'].apply(literal_eval)
# df1['mencions'] = df1['mencions'].apply(literal_eval)
df1.set_index('fecha', inplace=True)

df = pd.read_csv('data/tw.csv')

df['fecha'] = pd.to_datetime(df['fecha'])
df['create_count'] = pd.to_datetime(df['create_count'])
# df['hashtags'] = df['hashtags'].apply(literal_eval)
# df['mencions'] = df['mencions'].apply(literal_eval)
df.set_index('fecha', inplace=True)

# %%
len(df1),len(df), 85160
# Out:
# (16389, 68771, 85160)

# %%
da = pd.concat([df,df1]).drop_duplicates()

# %%
pd.concat([da['16/01/2021'],da['17/01/2021']]).to_csv('tweets_debate.csv')

# %%
len(data)
# Out:
# 85099

# %%
da.to_csv('tweets.csv')
